# %% [markdown]
# # Description
# We want to obtain a keyword influence graph. Its nodes are keyphrases of AI and Renewable Energy patents and its edges are given by the Katz influence (directed path aggregates) in the patent citation network. Node weights are given by keyword count and edge weights by Katz influence.

# %%
import pandas as pd
from keyphrase_vectorizers import KeyphraseCountVectorizer
from keybert import KeyBERT
import pickle
import networkx as nx
# Out:
# c:\Users\test\anaconda3\lib\site-packages\scipy\__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.1
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %% [markdown]
# # Gathering the data

# %%
AI_patents=pd.read_csv('../databases/AI_patents.csv' , dtype={'patent_number': object})
AI_patents=AI_patents[AI_patents.patent_number.astype(str).str.isnumeric()]
AI_patents.head()
# Out:
#    Unnamed: 0  meanSPNPcited_1year_before  filing_year patent_number  \
# 0           0                   -2.589326         2015      10000124
# 1           1                   -1.441175         2016      10001422
# 2           2                   -1.728041         2015      10001763
# 3           3                   -3.980396         2016      10001778
# 4           4                   -3.207635         2016      10001780
#
#    RPbyYear group_id                                        subgroup_id  \
# 0  0.516084     Y02T  ['Y02T10/645', 'B60W10/08', 'B60W2710/18', 'B6...
# 1  0.688590     G01L  ['G01L1/16', 'G06N3/008', 'A61B2562/0247', 'A6...
# 2  0.641872     G05B        ['G05B15/02', 'G05B2219/2642', 'G06N5/025']
# 3  0.347794     G05D  ['G05D1/0011', 'G05D13/00', 'G05D1/0088', 'G08...
# 4  0.430521     G01C  ['G01C21/3415', 'G05D1/0276', 'G05D1/0214', 'G...
#
#                                             abstract  \
# 0  Systems, apparatus and methods to multiple lev...
# 1  A pain sensing device includes a sensor array ...
# 2  A method for controlling intelligent device ba...
# 3  Systems and methods for controlling an unmanne...
# 4  Systems and methods for dynamic route planning...
#
#                                                title
# 0  Independent steering, power, torque control an...
# 1                 Method and device for sensing pain
# 2  Control device and method for controlling inte...
# 3    Velocity control for an unmanned aerial vehicle
# 4  Systems and methods for dynamic route planning...

# %%
lcet=pd.read_csv('output/LCET_patents_with_influencers.csv')  
lcet.head()
# Out:
#    Unnamed: 0  Patent number  Patent year Technology type   CPC class  \
# 0           0           94.0         1836           hydro  Y02E10/226
# 1           1          479.0         1837            wind  Y02E10/723
# 2           2          512.0         1837           hydro  Y02E10/223
# 3           3          518.0         1837           hydro  Y02E10/223
# 4           4          695.0         1838           hydro  Y02E10/223
#
#    Patent date                            Patent title  patent_number_x  \
# 0     18361128           Reacting sotaxy  steak-engine              NaN
# 1     18371123                Improvement in windmills              NaN
# 2     18371215                             Water-wheel              NaN
# 3     18371215  Improvement in horizontal water-wheels              NaN
# 4     18380416                    Improved water-wheel              NaN
#
#   AI_influencers  patent_number_y influencing_AI_subdomains  patent_number  \
# 0            NaN              NaN                       NaN            NaN
# 1            NaN              NaN                       NaN            NaN
# 2            NaN              NaN                       NaN            NaN
# 3            NaN              NaN                       NaN            NaN
# 4            NaN              NaN                       NaN            NaN
#
#   influencing_AI_keywords
# 0                     NaN
# 1                     NaN
# 2                     NaN
# 3                     NaN
# 4                     NaN

# %%
AI_patents['Technology type']=['AI']* AI_patents.shape[0]
lcet['patent_number']=lcet['Patent number']


lcet['patent_number']=lcet['patent_number'].apply(lambda x: int(x))
lcet=lcet[lcet.patent_number.astype(str).str.isdigit()]
lcet.patent_number=lcet.patent_number.astype(int)

# %%
AI_patents=AI_patents[['patent_number', 'Technology type']]
lcet=lcet[['patent_number', 'Technology type', "AI_influencers"]]

# %%
lcet=pd.DataFrame(lcet.groupby('patent_number').first())

# %%
lcet['patent_number']=lcet.index
lcet
# Out:
#               Technology type  \
# patent_number
# 94                      hydro
# 479                      wind
# 512                     hydro
# 518                     hydro
# 695                     hydro
# ...                       ...
# 10218298                 wind
# 10218304              thermal
# 10218306              thermal
# 10218307                   pv
# 10219329                 wind
#
#                                                   AI_influencers  \
# patent_number
# 94                                                          None
# 479                                                         None
# 512                                                         None
# 518                                                         None
# 695                                                         None
# ...                                                          ...
# 10218298       [('4523331', 0.00028211099074559984), ('532177...
# 10218304       [('4748674', 0.0013060694015999993), ('4105998...
# 10218306       [('4736447', 0.0013060694015999993), ('4651297...
# 10218307       [('5138928', 0.002176782335999999), ('5187592'...
# 10219329       [('4435837', 0.0013060694015999993), ('4011547...
#
#                patent_number
# patent_number
# 94                        94
# 479                      479
# 512                      512
# 518                      518
# 695                      695
# ...                      ...
# 10218298            10218298
# 10218304            10218304
# 10218306            10218306
# 10218307            10218307
# 10219329            10219329
#
# [65305 rows x 3 columns]

# %%
DF=pd.concat([AI_patents,lcet])
DF.patent_number=DF.patent_number.astype('int')

# %%
DF
# Out:
#           patent_number Technology type  \
# 0              10000124              AI
# 1              10001422              AI
# 2              10001763              AI
# 3              10001778              AI
# 4              10001780              AI
# ...                 ...             ...
# 10218298       10218298            wind
# 10218304       10218304         thermal
# 10218306       10218306         thermal
# 10218307       10218307              pv
# 10219329       10219329            wind
#
#                                              AI_influencers
# 0                                                       NaN
# 1                                                       NaN
# 2                                                       NaN
# 3                                                       NaN
# 4                                                       NaN
# ...                                                     ...
# 10218298  [('4523331', 0.00028211099074559984), ('532177...
# 10218304  [('4748674', 0.0013060694015999993), ('4105998...
# 10218306  [('4736447', 0.0013060694015999993), ('4651297...
# 10218307  [('5138928', 0.002176782335999999), ('5187592'...
# 10219329  [('4435837', 0.0013060694015999993), ('4011547...
#
# [85283 rows x 3 columns]

# %%
DF=DF[~DF["Technology type"].isin(['fission', 'fusion'])]

# %%
pats=pd.read_csv("../databases/patent.tsv", sep='\t', usecols=['id', 'abstract']) 

pats=pats[pats.id.astype(str).str.isdigit()]
pats.id=pats.id.astype(int)

pats
# Out:
# C:\Users\test\AppData\Local\Temp/ipykernel_54736/801688226.py:1: DtypeWarning: Columns (0,5) have mixed types. Specify dtype option on import or set low_memory=False.
#   pats=pd.read_csv("../databases/patent.tsv", sep='\t', usecols=['id', 'abstract'])
#                id                                           abstract
# 0        10000000  A frequency modulated (coherent) laser detecti...
# 1        10000001  The injection molding machine includes a fixed...
# 2        10000002  The present invention relates to: a method for...
# 3        10000003  The invention relates to a method for producin...
# 4        10000004  The present invention relates to provides a do...
# ...           ...                                                ...
# 7430868   T998013                                                NaN
# 7430869   T998014                                                NaN
# 7430870   T999001                                                NaN
# 7430871   T999002                                                NaN
# 7430872   T999003                                                NaN
#
# [7430873 rows x 2 columns]

# %%
pats=pats.groupby('id').first()

# %%
DF=DF.merge(pats, how='inner', left_on='patent_number', right_on='id')

# %%
DF=DF.reindex()
DF
# Out:
#        patent_number Technology type  \
# 0           10000124              AI
# 1           10001422              AI
# 2           10001763              AI
# 3           10001778              AI
# 4           10001780              AI
# ...              ...             ...
# 67390       10218298            wind
# 67391       10218304         thermal
# 67392       10218306         thermal
# 67393       10218307              pv
# 67394       10219329            wind
#
#                                           AI_influencers  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 67390  [('4523331', 0.00028211099074559984), ('532177...
# 67391  [('4748674', 0.0013060694015999993), ('4105998...
# 67392  [('4736447', 0.0013060694015999993), ('4651297...
# 67393  [('5138928', 0.002176782335999999), ('5187592'...
# 67394  [('4435837', 0.0013060694015999993), ('4011547...
#
#                                                 abstract
# 0      Systems, apparatus and methods to multiple lev...
# 1      A pain sensing device includes a sensor array ...
# 2      A method for controlling intelligent device ba...
# 3      Systems and methods for controlling an unmanne...
# 4      Systems and methods for dynamic route planning...
# ...                                                  ...
# 67390  Systems and methods for controlling reactive c...
# 67391  A roof mount assembly mounts a structure to a ...
# 67392  In various representative aspects, an assembly...
# 67393  A connection box for solar panels to enable th...
# 67394  A method of fabricating a thermoplastic compon...
#
# [67395 rows x 4 columns]

# %%
DF=DF.groupby('patent_number').first()
DF
# Out:
#               Technology type AI_influencers  \
# patent_number
# 3930750                  wind           None
# 3933628               thermal           None
# 3934323               thermal           None
# 3934573               thermal           None
# 3934643               thermal           None
# ...                       ...            ...
# 10701321                   AI           None
# 10701353                   AI           None
# 10701434                   AI           None
# 10701489                   AI           None
# 10701562                   AI           None
#
#                                                         abstract
# patent_number
# 3930750         A power plant of the windmill type is provide...
# 3933628         This invention relates to an improved anaerob...
# 3934323         A panel having multiple tubular passages exte...
# 3934573         A spherical system for the concentration and ...
# 3934643         A heat pipe comprising a hermetically sealed ...
# ...                                                          ...
# 10701321       A system and method for distributed analysis o...
# 10701353       A system is disclosed, comprising a data proce...
# 10701434       A seek content extraction system analyzes fram...
# 10701489       A wearable device for binaural audio is descri...
# 10701562       Blocking of undesirable voice over internet pr...
#
# [67367 rows x 3 columns]

# %% [markdown]
# # Obtaining patent keywords

# %%
kw_model = KeyBERT()

def get_keyphrases(docs):
    keyphrases=kw_model.extract_keywords(docs=docs, keyphrase_ngram_range = (1, 3),  stop_words='english' ,
                                          use_mmr=True, diversity=0.6) #, use_maxsum=True, top_n=5, nr_candidates=20) vectorizer=KeyphraseCountVectorizer()

    #keyphrases= [sorted(kws,key=lambda x: x[0], reverse=True) for kws in keyphrases]
    return   keyphrases

# %%
DF['keywords']=get_keyphrases(list(DF.abstract.astype(str).values))

# %%
DF.keywords[7728715]
# Out:
# [('remote monitoring', 0.6483),
#  ('digital image containing', 0.5042),
#  ('signal containing information', 0.4366),
#  ('cmos', 0.3909),
#  ('parking spaces items', 0.153)]

# %%
DF.to_csv("output/AI_LCET_keywords_keybert_final.tsv", sep='\t')

# %%
import pandas as pd
from ast import literal_eval

DF=pd.read_csv('output/AI_LCET_keywords_keybert.tsv', sep='\t')
DF.set_index('patent_number', drop=True, inplace=True)
DF.keywords=DF.astype(str).keywords.apply(lambda x : x.split(',')) #literal_eval)
DF
# Out:
#                Unnamed: 0 Technology type AI_influencers  \
# patent_number
# 3930750             20006            wind            NaN
# 3933628             20007         thermal            NaN
# 3934323             20008         thermal            NaN
# 3934573             20009         thermal            NaN
# 3934643             20010         thermal            NaN
# ...                   ...             ...            ...
# 10701321             6195              AI            NaN
# 10701353             6196              AI            NaN
# 10701434             6197              AI            NaN
# 10701489             6198              AI            NaN
# 10701562             6199              AI            NaN
#
#                                                         abstract  \
# patent_number
# 3930750         A power plant of the windmill type is provide...
# 3933628         This invention relates to an improved anaerob...
# 3934323         A panel having multiple tubular passages exte...
# 3934573         A spherical system for the concentration and ...
# 3934643         A heat pipe comprising a hermetically sealed ...
# ...                                                          ...
# 10701321       A system and method for distributed analysis o...
# 10701353       A system is disclosed, comprising a data proce...
# 10701434       A seek content extraction system analyzes fram...
# 10701489       A wearable device for binaural audio is descri...
# 10701562       Blocking of undesirable voice over internet pr...
#
#                                                         keywords
# patent_number
# 3930750        [windmill type, wind tracking mechanisms, prop...
# 3933628        [anaerobic digestion apparatus, pond therebene...
# 3934323        [panels, flows, fluid tight hollow header, mel...
# 3934573        [boiler, solar energy, spherical system, appar...
# 3934643        [heat pipe, saturated vapor, communicates, hol...
# ...                                                          ...
# 10701321       [video surveillance system, only image data, c...
# 10701353       [imaging system, processing, exemplary pattern...
# 10701434       [seek content extraction system, video content...
# 10701489       [binaural audio, wearable device, ambient nois...
# 10701562       [voip communication, blocking, phishing scheme...
#
# [67367 rows x 5 columns]

# %%
bad_keywords=['photovoltaic', 'disclosed', 'semiconductor substrate', 'solar', 'wind', 'apparatus', 'present invention', 'turbine',
'methods', 'neural', 'wind turbine comprising', 'processing', 'compounds', 'method', "detecting", 'electronic device']

# %% [markdown]
# # Computing graph weights

# %%
num_keywords=3
df=DF


edge_weights={}
node_weights={}

for i, X in df.iterrows():
    Type=X["Technology type"]
    for kw1 in X.keywords[:num_keywords]: #,s
        #if len(kw1.split())==1:
        #    continue
        if kw1 in bad_keywords:
                continue
        if kw1=='solar cells':
             kw1='solar cell'
        if kw1=='photovoltaic cells':
             kw1='photovoltaic cell'  
        if kw1=='photovoltaic devices':
             kw1='photovoltaic device'
        if kw1=='wind turbines':
             kw1='wind turbine' 
        if kw1 in ['classification', 'classifier', 'classifying']:
             kw1='classifier'

        if kw1 in ['digital image', 'image data', 'image processing','image processing apparatus']:
             kw1='image processing'
        if kw1== 'machine learning model':
             kw1= 'machine learning'
        if Type=="thermal" and kw1=='solar panel' or kw1=='solar panels' or kw1=="panels":
             continue     
        if kw1=='system' or kw1=="solar energy" or kw1==  'second electrode':
             continue 
        if kw1=='solar collectors':
            kw1='solar collector'
        if kw1=='electrodes':
            kw1='electrode' 
        if kw1== 'electronic devices':
            kw1= 'electronic device'
        if kw1=='fabricating':
             kw1=  'manufacturing'
        if kw1=='polymers':
             kw1='polymer'  
        if kw1=='wind power':
             kw1="wind energy"
        if kw1=='solar energy collector':
             kw1= 'solar heat collector',           
       
        
 
 
        
        Type=X["Technology type"]
        if (kw1, Type) in node_weights:
            node_weights[(kw1, Type)]+=1#s
        else:
             node_weights[(kw1, Type)]=1#s

        if X.AI_influencers==None or type(X.AI_influencers)==float:
            continue  # Nans
        if Type=="AI":
             continue #AI influence on AI is excluded
        for AIpat, s_AI in literal_eval(X.AI_influencers):

                for kw2 in df.keywords[int(AIpat)][:num_keywords]: #,s_RET
                    #if len(kw2.split())==1:
                    #    continue
                    if kw2 in bad_keywords:
                         continue

                    if ((kw2, "AI"),(kw1, Type))  in edge_weights.keys():
                        edge_weights[((kw2, "AI"),(kw1, Type))  ]+=s_AI#*s_RET
                    else:
                        edge_weights[(( kw2,"AI"),( kw1, Type))  ]=s_AI#*s_RET

# %%
#sort node_weights by value

def sort_weights(node_weights):
    return sorted(node_weights.items(), key=lambda x: x[1], reverse=True)

sorted_node_weights=sort_weights(node_weights)
sorted_edge_weights=sort_weights(edge_weights)

sorted_node_weights
# Out:
# [(('solar cell', 'pv'), 2196),
#  (('wind turbine', 'wind'), 1655),
#  (('substrate', 'pv'), 823),
#  (('photovoltaic device', 'pv'), 607),
#  (('manufacturing', 'pv'), 501),
#  (('image processing', 'AI'), 492),
#  (('classifier', 'AI'), 469),
#  (('solar collector', 'thermal'), 443),
#  (('photovoltaic cell', 'pv'), 410),
#  (('neural network', 'AI'), 332),
#  (('thin film', 'pv'), 296),
#  (('fermentation', 'biofuel'), 275),
#  (('semiconductor device', 'pv'), 261),
#  (('wind turbine blade', 'wind'), 259),
#  (('semiconductor', 'pv'), 247),
#  (('biomass', 'biofuel'), 244),
#  (('solar cell module', 'pv'), 242),
#  (('ethanol', 'biofuel'), 238),
#  (('autonomous vehicle', 'AI'), 234),
#  ((('solar heat collector',), 'thermal'), 216),
#  (('machine learning', 'AI'), 204),
#  (('electrode', 'pv'), 198),
#  (('polymer', 'pv'), 189),
#  (('etching', 'pv'), 186),
#  (('wind energy', 'wind'), 184),
#  (('dye sensitized solar cell', 'pv'), 184),
#  (('generator', 'wind'), 181),
#  (('wind turbine generator', 'wind'), 165),
#  (('biodiesel', 'biofuel'), 164),
#  (('rotor', 'wind'), 163),
#  (('photoelectric conversion device', 'pv'), 157),
#  (('display device', 'pv'), 154),
#  (('process', 'biofuel'), 152),
#  (('semiconductor layer', 'pv'), 147),
#  (('rotor blade', 'wind'), 145),
#  (('mounting', 'thermal'), 139),
#  (('photovoltaic module', 'pv'), 137),
#  (('computing device', 'AI'), 125),
#  (('nucleic acid constructs', 'biofuel'), 123),
#  (('inverter', 'pv'), 122),
#  (('silicon solar cell', 'pv'), 115),
#  (('solar radiation', 'thermal'), 113),
#  (('expert system', 'AI'), 109),
#  (('solar heat collector', 'thermal'), 108),
#  (('solar battery', 'pv'), 108),
#  (('wind power plant', 'wind'), 107),
#  (('silicon substrate', 'pv'), 106),
#  (('monitoring', 'AI'), 104),
#  (('photodetector', 'pv'), 103),
#  (('database', 'AI'), 100),
#  (('windmill', 'wind'), 99),
#  (('organic electronic device', 'pv'), 98),
#  (('organic light', 'pv'), 97),
#  (('controlling', 'wind'), 94),
#  (('optoelectronic device', 'pv'), 94),
#  (('biofuels', 'biofuel'), 93),
#  (('emitting device', 'pv'), 90),
#  (('solar concentrator', 'thermal'), 87),
#  (('electronic device', 'pv'), 86),
#  (('isolated polypeptides', 'biofuel'), 86),
#  (('systems', 'AI'), 86),
#  (('amorphous silicon', 'pv'), 85),
#  (('artificial neural network', 'AI'), 85),
#  (('solar cell comprising', 'pv'), 84),
#  (('manufacturing method', 'pv'), 84),
#  (('flexible substrate', 'pv'), 84),
#  (('ethanol production', 'biofuel'), 83),
#  (('nacelle', 'wind'), 83),
#  (('features', 'AI'), 83),
#  (('device', 'pv'), 82),
#  (('tracking', 'AI'), 82),
#  (('vehicle', 'AI'), 82),
#  (('substrates', 'pv'), 81),
#  (('heat exchanger', 'thermal'), 81),
#  (('semiconductor material', 'pv'), 81),
#  (('plant biomass', 'biofuel'), 81),
#  (('energy', 'thermal'), 80),
#  (('photodiode', 'pv'), 80),
#  (('photoelectric', 'pv'), 79),
#  (('wind power installation', 'wind'), 79),
#  (('optoelectronic devices', 'pv'), 79),
#  (('lignocellulosic biomass', 'biofuel'), 78),
#  (('compound', 'pv'), 77),
#  (('sunlight', 'thermal'), 76),
#  (('wind turbine rotor blade', 'wind'), 76),
#  (('knowledge base', 'AI'), 76),
#  (('vertical axis wind turbine', 'wind'), 75),
#  (('computer system', 'AI'), 75),
#  (('silicon', 'pv'), 74),
#  (('solar panel', 'pv'), 74),
#  (('robot', 'AI'), 74),
#  (('photovoltaic modules', 'pv'), 74),
#  (('photoelectric conversion element', 'pv'), 74),
#  (('efficiency', 'pv'), 73),
#  (('feedstock materials', 'biofuel'), 73),
#  (('generator', 'hydro'), 72),
#  (('support structure', 'thermal'), 72),
#  (('blades', 'wind'), 71),
#  (('invention', 'pv'), 71),
#  (('photoelectric conversion', 'pv'), 71),
#  (('absorber layer', 'pv'), 71),
#  (('bearing', 'wind'), 70),
#  (('pyrolysis', 'biofuel'), 70),
#  (('device', 'AI'), 70),
#  (('flexible display', 'pv'), 70),
#  (('solar heating system', 'thermal'), 69),
#  (('methane', 'waste'), 69),
#  (('panel', 'thermal'), 69),
#  (('solar cell comprises', 'pv'), 69),
#  (('reflective', 'thermal'), 68),
#  (('user interface', 'AI'), 68),
#  (('process', 'pv'), 67),
#  (('solar module', 'pv'), 67),
#  (('wind turbine tower', 'wind'), 66),
#  (('training data', 'AI'), 66),
#  (('recognition', 'AI'), 65),
#  (('organic', 'pv'), 65),
#  (('speech recognition', 'AI'), 65),
#  (('transparent electrode', 'pv'), 64),
#  (('biofuel', 'biofuel'), 64),
#  (('disclosure', 'AI'), 63),
#  (('geothermal', 'geo'), 62),
#  (('reflector', 'thermal'), 62),
#  (('rotor blades', 'wind'), 62),
#  (('isolated polynucleotides encoding', 'biofuel'), 62),
#  (('solar cell device', 'pv'), 61),
#  (('biogas', 'waste'), 61),
#  (('organic light emitting diode', 'pv'), 61),
#  (('pattern recognition', 'AI'), 60),
#  (('systems methods', 'AI'), 60),
#  (('reflectors', 'thermal'), 59),
#  (('cellulose', 'biofuel'), 59),
#  (('thin films', 'pv'), 59),
#  (('producing', 'biofuel'), 59),
#  (('glass substrate', 'pv'), 59),
#  (('solar cell substrate', 'pv'), 59),
#  (('unmanned aerial vehicle', 'AI'), 59),
#  (('solar heating', 'thermal'), 58),
#  (('light', 'pv'), 58),
#  (('tower', 'wind'), 58),
#  (('autonomous', 'AI'), 58),
#  (('wind generator', 'wind'), 57),
#  (('wind power generator', 'wind'), 57),
#  (('sensor data', 'AI'), 57),
#  (('mobile device', 'AI'), 57),
#  (('hydraulic turbine', 'hydro'), 56),
#  (('solar receiver', 'thermal'), 56),
#  (('flexible display device', 'pv'), 56),
#  (('embodiments', 'AI'), 56),
#  (('anaerobic digestion', 'waste'), 55),
#  (('absorber', 'thermal'), 55),
#  (('waves', 'sea'), 55),
#  (('generating', 'wind'), 55),
#  (('blade', 'wind'), 55),
#  (('photovoltaic system', 'pv'), 55),
#  (('object detection', 'AI'), 55),
#  (('semiconductor devices', 'pv'), 54),
#  (('tracking', 'thermal'), 54),
#  (('hydraulic machine', 'hydro'), 53),
#  (('transparent conductive', 'pv'), 53),
#  (('composition', 'pv'), 53),
#  (('decision tree', 'AI'), 53),
#  (('objects', 'AI'), 53),
#  (('formula', 'pv'), 53),
#  (('process', 'waste'), 52),
#  (('cell', 'pv'), 52),
#  (('flexible', 'pv'), 52),
#  (('optical device', 'pv'), 52),
#  (('clustering', 'AI'), 52),
#  (('organic electronic devices', 'pv'), 52),
#  (('plurality', 'pv'), 51),
#  (('producing', 'pv'), 51),
#  (('photovoltaic element', 'pv'), 51),
#  (('real time', 'AI'), 51),
#  (('recognizing', 'AI'), 51),
#  (('wind turbine blades', 'wind'), 51),
#  (('thin film photovoltaic device', 'pv'), 51),
#  (('predicting', 'AI'), 51),
#  (('organic electroluminescent devices', 'pv'), 51),
#  (('wave energy', 'sea'), 50),
#  (('stator', 'wind'), 50),
#  (('genetic algorithm', 'AI'), 50),
#  (('oled', 'pv'), 50),
#  (('machine learning algorithm', 'AI'), 50),
#  (('solar heat', 'thermal'), 49),
#  (('structure', 'pv'), 49),
#  (('image processing device', 'AI'), 49),
#  (('photovoltaic modules', 'thermal'), 49),
#  (('analyzing', 'AI'), 49),
#  (('polypeptides', 'biofuel'), 49),
#  (('question answering', 'AI'), 49),
#  (('augmented reality', 'AI'), 49),
#  (('solar heater', 'thermal'), 48),
#  (('heat transfer', 'thermal'), 48),
#  (('sun', 'thermal'), 48),
#  (('structure', 'thermal'), 48),
#  (('water turbine', 'hydro'), 48),
#  (('solar cell', 'thermal'), 48),
#  (('information processing apparatus', 'AI'), 48),
#  (('absorbing', 'thermal'), 47),
#  (('generators', 'wind'), 47),
#  (('adhesive', 'pv'), 47),
#  (('energy', 'sea'), 47),
#  (('conductive paste', 'pv'), 47),
#  (('fermentable sugars', 'biofuel'), 47),
#  (('wind turbine system', 'wind'), 47),
#  (('segmenting', 'AI'), 47),
#  (('images', 'AI'), 47),
#  (('vanes', 'wind'), 46),
#  (('transparent substrate', 'pv'), 46),
#  (('pn junction', 'pv'), 46),
#  (('mounting', 'wind'), 46),
#  (('wind turbine rotor', 'wind'), 46),
#  (('photoelectric conversion layer', 'pv'), 46),
#  (('detection', 'AI'), 46),
#  (('computer program product', 'AI'), 46),
#  (('cooling', 'wind'), 45),
#  (('transparent conductive film', 'pv'), 45),
#  (('sensor', 'AI'), 45),
#  (('organic photovoltaic', 'pv'), 45),
#  (('heat', 'thermal'), 44),
#  (('heterojunction', 'pv'), 44),
#  (('semiconductor layers', 'pv'), 44),
#  (('dye', 'pv'), 44),
#  (('generation', 'wind'), 44),
#  (('forming', 'pv'), 44),
#  (('feature extraction', 'AI'), 44),
#  (('extracting', 'AI'), 44),
#  (('data', 'AI'), 44),
#  (('assembling', 'wind'), 44),
#  (('roof', 'thermal'), 43),
#  (('concentrating', 'thermal'), 43),
#  (('transparent', 'pv'), 43),
#  (('thin film photovoltaic', 'pv'), 43),
#  (('monitoring', 'wind'), 43),
#  (('sensing', 'AI'), 43),
#  (('gasification', 'biofuel'), 42),
#  (('solar cell structure', 'pv'), 42),
#  (('adaptive', 'AI'), 42),
#  (('convolutional neural network', 'AI'), 42),
#  (('heating', 'thermal'), 41),
#  (('substrate comprising', 'pv'), 41),
#  (('wind energy plant', 'wind'), 41),
#  (('module', 'pv'), 41),
#  (('image sensor', 'pv'), 41),
#  (('camera', 'AI'), 41),
#  (('heat exchange', 'thermal'), 40),
#  (('panel', 'pv'), 40),
#  (('controlling', 'pv'), 40),
#  (('silicon wafer', 'pv'), 40),
#  (('controlling', 'AI'), 40),
#  (('nanoparticles', 'pv'), 40),
#  (('cellulosic biomass', 'biofuel'), 40),
#  (('fastener', 'thermal'), 40),
#  (('cellulosic material', 'biofuel'), 39),
#  (('collector', 'thermal'), 39),
#  (('optical', 'pv'), 39),
#  (('type semiconductor', 'pv'), 39),
#  (('deposition', 'pv'), 39),
#  (('amorphous', 'pv'), 39),
#  (('biomass', 'waste'), 39),
#  (('light receiving', 'pv'), 39),
#  (('controller', 'AI'), 39),
#  (('classifiers', 'AI'), 39),
#  (('display apparatus', 'pv'), 39),
#  (('solar heat collecting', 'thermal'), 38),
#  (('heat absorbing', 'thermal'), 38),
#  (('solar energy system', 'thermal'), 38),
#  (('cells', 'pv'), 38),
#  (('damping', 'wind'), 38),
#  (('conductive', 'pv'), 38),
#  (('fermentation product', 'biofuel'), 38),
#  (('image processing system', 'AI'), 38),
#  (('solar battery module', 'pv'), 38),
#  (('light absorbing layer', 'pv'), 38),
#  (('support vector machine', 'AI'), 38),
#  (('generating', 'AI'), 38),
#  (('solar energy collecting', 'thermal'), 37),
#  (('ocean thermal energy conversion', 'sea'), 37),
#  (('object recognition', 'AI'), 37),
#  (('thin film transistor', 'pv'), 37),
#  (('medical images', 'AI'), 37),
#  (('polynucleotides', 'biofuel'), 37),
#  (('graphene', 'pv'), 37),
#  (('plurality', 'wind'), 36),
#  (('energy', 'hydro'), 36),
#  (('adhesive layer', 'pv'), 36),
#  (('airfoils', 'wind'), 36),
#  (('photovoltaic cell comprising', 'pv'), 36),
#  (('yeast', 'biofuel'), 36),
#  (('glucosidase', 'biofuel'), 36),
#  (('wave energy converter', 'sea'), 36),
#  (('patterns', 'AI'), 36),
#  (('catalyst', 'biofuel'), 36),
#  (('sensing', 'pv'), 36),
#  (('solar cell module comprises', 'pv'), 36),
#  (('inverters', 'pv'), 36),
#  (('graphical user interface', 'AI'), 36),
#  (('recombinant microorganisms', 'biofuel'), 36),
#  (('bending', 'pv'), 36),
#  (('concentrator', 'thermal'), 35),
#  (('flow', 'hydro'), 35),
#  (('airfoil', 'wind'), 35),
#  (('synthesis gas', 'biofuel'), 35),
#  (('heliostat', 'thermal'), 35),
#  (('rotation', 'wind'), 35),
#  (('solar energy collection system', 'thermal'), 35),
#  (('amorphous silicon layer', 'pv'), 35),
#  (('layer', 'pv'), 35),
#  (('wastewater', 'waste'), 35),
#  (('intrinsic layer', 'pv'), 35),
#  (('passivation layer', 'pv'), 35),
#  (('second electrodes', 'pv'), 35),
#  (('similarity', 'AI'), 35),
#  (('image', 'AI'), 35),
#  (('maximum power point tracking', 'pv'), 35),
#  (('computer program', 'AI'), 35),
#  (('organic optoelectronic device', 'pv'), 35),
#  (('power grid', 'pv'), 35),
#  (('reflective surface', 'thermal'), 34),
#  (('generator', 'sea'), 34),
#  (('radiant energy', 'thermal'), 34),
#  (('radiation', 'thermal'), 34),
#  (('solar pond', 'thermal'), 34),
#  (('solar thermal', 'thermal'), 34),
#  (('rotor hub', 'wind'), 34),
#  (('input image', 'AI'), 34),
#  (('solar cell module comprising', 'pv'), 34),
#  (('predictive model', 'AI'), 34),
#  (('transesterification', 'biofuel'), 34),
#  (('clusters', 'AI'), 34),
#  (('processor', 'AI'), 34),
#  (('face detection', 'AI'), 34),
#  (('corpus', 'AI'), 34),
#  (('electrical machine', 'wind'), 34),
#  (('deep neural network', 'AI'), 34),
#  (('flexible display panel', 'pv'), 34),
#  (('generating', 'hydro'), 33),
#  (('avalanche photodiode', 'pv'), 33),
#  (('control system', 'wind'), 33),
#  (('solar cell apparatus', 'pv'), 33),
#  (('feature', 'AI'), 33),
#  (('imaging device', 'AI'), 33),
#  (('photoelectric conversion device comprising', 'pv'), 33),
#  (('photovoltaic module', 'thermal'), 33),
#  (('recurrent neural network', 'AI'), 33),
#  (('compositions', 'biofuel'), 33),
#  (('transgenic plants', 'biofuel'), 33),
#  (('search engine', 'AI'), 33),
#  (('copolymer', 'pv'), 33),
#  (('autonomous vehicles', 'AI'), 33),
#  (('electrical generator', 'wind'), 32),
#  (('solar tracking', 'thermal'), 32),
#  (('wave', 'sea'), 32),
#  (('produce', 'biofuel'), 32),
#  (('encapsulating', 'pv'), 32),
#  (('fermentation process', 'biofuel'), 32),
#  (('variable speed wind turbine', 'wind'), 32),
#  (('dc converter', 'pv'), 32),
#  (('buffer layer', 'pv'), 32),
#  (('feature vectors', 'AI'), 32),
#  (('nodes', 'AI'), 32),
#  (('uav', 'AI'), 32),
#  (('deep learning', 'AI'), 32),
#  (('thermal energy', 'thermal'), 31),
#  (('isolation', 'pv'), 31),
#  (('cooling', 'thermal'), 31),
#  (('wave motion', 'sea'), 31),
#  (('energy', 'wind'), 31),
#  (('conductive adhesive', 'pv'), 31),
#  (('photoconductive layer', 'pv'), 31),
#  (('microorganisms', 'biofuel'), 31),
#  (('photoactive layer', 'pv'), 31),
#  (('image recognition', 'AI'), 31),
#  (('solar modules', 'thermal'), 31),
#  (('organic solar cell', 'pv'), 31),
#  (('image processing method', 'AI'), 31),
#  (('fatty acid alkyl esters', 'biofuel'), 31),
#  (('plurality', 'AI'), 31),
#  (('models', 'AI'), 31),
#  (('power generation system', 'wind'), 31),
#  (('wind farm', 'wind'), 31),
#  (('training images', 'AI'), 31),
#  (('biomass feedstocks', 'biofuel'), 31),
#  (('rotor', 'hydro'), 30),
#  (('anode', 'pv'), 30),
#  (('hub', 'wind'), 30),
#  (('solar collector comprising', 'thermal'), 30),
#  (('mirror', 'thermal'), 30),
#  (('charging', 'pv'), 30),
#  (('support structure', 'wind'), 30),
#  (('copolymers', 'pv'), 30),
#  (('back contact', 'pv'), 30),
#  (('anaerobic digester', 'waste'), 30),
#  (('photovoltaic panel', 'pv'), 30),
#  (('fuzzy logic', 'AI'), 30),
#  (('analysis', 'AI'), 30),
#  (('imaging', 'AI'), 30),
#  (('organic light emitting diodes', 'pv'), 30),
#  (('carbon nanotubes', 'pv'), 30),
#  (('generate', 'AI'), 30),
#  (('wind turbine nacelle', 'wind'), 30),
#  (('utility grid', 'wind'), 30),
#  (('social network', 'AI'), 30),
#  (('municipal waste biomass', 'biofuel'), 30),
#  (('heat exchanger', 'geo'), 29),
#  (('modules', 'pv'), 29),
#  (('ocean waves', 'sea'), 29),
#  (('geothermal energy', 'geo'), 29),
#  (('junction solar cell', 'pv'), 29),
#  (('solar array', 'pv'), 29),
#  (('conductive substrate', 'pv'), 29),
#  (('solar cell having', 'pv'), 29),
#  (('photovoltaic device comprises', 'pv'), 29),
#  (('semiconductors', 'pv'), 29),
#  (('multijunction', 'pv'), 29),
#  (('reflection', 'pv'), 29),
#  (('lignocellulosic material', 'biofuel'), 29),
#  (('artificial intelligence', 'AI'), 29),
#  (('patterning', 'pv'), 29),
#  (('metal complexes', 'pv'), 29),
#  (('support substrate', 'pv'), 29),
#  (('wind turbine comprises', 'wind'), 29),
#  (('attributes', 'AI'), 29),
#  (('medical image', 'AI'), 29),
#  (('electroluminescent devices', 'pv'), 29),
#  (('wind power generation', 'wind'), 29),
#  (('chemical formula', 'pv'), 29),
#  (('computing', 'AI'), 29),
#  (('present disclosure', 'AI'), 29),
#  (('embodiment', 'AI'), 29),
#  (('power generator', 'wind'), 28),
#  (('solar energy collection', 'thermal'), 28),
#  (('polycrystalline silicon', 'pv'), 28),
#  (('power system', 'pv'), 28),
#  (('doping', 'pv'), 28),
#  (('type semiconductor layer', 'pv'), 28),
#  (('electric generator', 'wind'), 28),
#  (('barrier', 'pv'), 28),
#  (('saccharification', 'biofuel'), 28),
#  (('substrate surface', 'pv'), 28),
#  (('solar tracker', 'thermal'), 28),
#  (('semiconducting', 'pv'), 28),
#  (('lignocellulosic materials', 'biofuel'), 28),
#  (('disclosure', 'pv'), 28),
#  (('inference engine', 'AI'), 28),
#  (('glucoamylase', 'biofuel'), 28),
#  (('insulating film', 'pv'), 28),
#  (('image information', 'AI'), 28),
#  (('sensors', 'AI'), 28),
#  (('solar module', 'thermal'), 28),
#  (('vehicle control', 'AI'), 28),
#  (('wind power installations', 'wind'), 28),
#  (('devices', 'AI'), 28),
#  (('dye sensitized solar cells', 'pv'), 28),
#  (('metadata', 'AI'), 28),
#  (('pump turbine', 'hydro'), 27),
#  (('evaporator', 'thermal'), 27),
#  (('gasification', 'waste'), 27),
#  (('epitaxial', 'pv'), 27),
#  (('solar cell panel', 'pv'), 27),
#  (('generating electricity', 'wind'), 27),
#  (('solar power', 'pv'), 27),
#  (('power generation', 'wind'), 27),
#  (('laminate', 'pv'), 27),
#  (('encapsulation', 'pv'), 27),
#  (('turbines', 'wind'), 27),
#  (('device comprises', 'pv'), 27),
#  (('memory', 'AI'), 27),
#  (('active layer', 'pv'), 27),
#  (('ram air turbine', 'wind'), 27),
#  (('passivation', 'pv'), 27),
#  (('classify', 'AI'), 27),
#  (('rotor shaft', 'wind'), 27),
#  (('clamp', 'thermal'), 27),
#  (('hidden markov model', 'AI'), 27),
#  (('quantum dots', 'pv'), 27),
#  (('processes', 'biofuel'), 27),
#  (('bayesian network', 'AI'), 27),
#  (('compositions', 'pv'), 27),
#  (('wind energy installation', 'wind'), 27),
#  (('learning', 'AI'), 27),
#  (('power grid', 'wind'), 27),
#  (('apparent border size', 'pv'), 27),
#  (('reflective coating', 'pv'), 26),
#  (('enzymatic hydrolysis', 'biofuel'), 26),
#  (('encapsulant', 'pv'), 26),
#  (('semiconductor region', 'pv'), 26),
#  (('energy', 'pv'), 26),
#  (('insulating layer', 'pv'), 26),
#  (('layers', 'pv'), 26),
#  (('flashing', 'thermal'), 26),
#  (('grid', 'pv'), 26),
#  (('starch', 'biofuel'), 26),
#  (('generation', 'hydro'), 26),
#  (('devices', 'pv'), 26),
#  (('second conductivity type', 'pv'), 26),
#  (('photoelectric conversion efficiency', 'pv'), 26),
#  (('conductive film', 'pv'), 26),
#  (('control system', 'AI'), 26),
#  (('triglycerides', 'biofuel'), 26),
#  (('natural language processing', 'AI'), 26),
#  (('second substrate', 'pv'), 26),
#  (('offshore wind turbine', 'wind'), 26),
#  (('blood flow', 'AI'), 26),
#  (('determining', 'AI'), 26),
#  (('documents', 'AI'), 26),
#  (('ontology', 'AI'), 26),
#  (('learning device', 'AI'), 26),
#  (('collecting', 'thermal'), 25),
#  (('radiation', 'pv'), 25),
#  (('electrical energy', 'hydro'), 25),
#  (('wafer', 'pv'), 25),
#  (('semiconductor wafer', 'pv'), 25),
#  (('solar cell modules', 'pv'), 25),
#  (('diode', 'pv'), 25),
#  (('flow', 'wind'), 25),
#  (('invention', 'wind'), 25),
#  (('ethanol fermentation', 'biofuel'), 25),
#  (('organic semiconductor', 'pv'), 25),
#  (('absorbing layer', 'pv'), 25),
#  (('wind energy system', 'wind'), 25),
#  (('horizontal axis wind turbine', 'wind'), 25),
#  (('bypass diode', 'pv'), 25),
#  (('solar modules', 'pv'), 25),
#  (('alpha amylase', 'biofuel'), 25),
#  (('information', 'AI'), 25),
#  (('matching', 'AI'), 25),
#  (('machine learning technique', 'AI'), 25),
#  (('image segmentation', 'AI'), 25),
#  (('machine learning techniques', 'AI'), 25),
#  (('data structure', 'AI'), 25),
#  (('ranking', 'AI'), 25),
#  (('aerodynamic profile', 'wind'), 25),
#  (('rotor blade assembly', 'wind'), 25),
#  (('enzymes', 'biofuel'), 25),
#  (('factual accuracy', 'AI'), 25),
#  (('convolutional neural', 'AI'), 25),
#  (('thermal', 'thermal'), 24),
#  (('geothermal brine', 'geo'), 24),
#  (('coating', 'pv'), 24),
#  (('sunlight', 'pv'), 24),
#  (('surface', 'pv'), 24),
#  (('apparatus comprises', 'pv'), 24),
#  (('absorber plate', 'thermal'), 24),
#  (('trailing edge', 'wind'), 24),
#  (('indium tin oxide', 'pv'), 24),
#  (('sputtering', 'pv'), 24),
#  (('invention', 'biofuel'), 24),
#  (('solar power system', 'thermal'), 24),
#  (('organic waste', 'waste'), 24),
#  (('photodetectors', 'pv'), 24),
#  (('bonding', 'pv'), 24),
#  (('hydrolysis', 'biofuel'), 24),
#  (('control', 'pv'), 24),
#  (('semiconductor light', 'pv'), 24),
#  (('germanium', 'pv'), 24),
#  (('digital images', 'AI'), 24),
#  (('second semiconductor layer', 'pv'), 24),
#  (('application', 'AI'), 24),
#  (('organic semiconductor material', 'pv'), 24),
#  (('polypeptide', 'biofuel'), 24),
#  (('data streams', 'AI'), 24),
#  (('processing device', 'AI'), 24),
#  (('gearbox', 'wind'), 24),
#  (('solar cell electrode', 'pv'), 24),
#  (('flexible display apparatus', 'pv'), 24),
#  (('biomass feedstock', 'biofuel'), 24),
#  (('electricity', 'wind'), 23),
#  (('solar water heater', 'thermal'), 23),
#  (('turbines', 'hydro'), 23),
#  (('device', 'thermal'), 23),
#  (('parabolic', 'thermal'), 23),
#  (('producing', 'waste'), 23),
#  (('electrical generator', 'hydro'), 23),
#  (('photovoltaic generator', 'pv'), 23),
#  (('wind turbine control', 'wind'), 23),
#  (('electrical energy', 'wind'), 23),
#  (('amorphous semiconductor', 'pv'), 23),
#  (('fluid flow', 'hydro'), 23),
#  (('xylose', 'biofuel'), 23),
#  (('photovoltaic solar cell', 'pv'), 23),
#  (('electrical power', 'wind'), 23),
#  (('signals', 'AI'), 23),
#  (('transparent conductive oxide', 'pv'), 23),
#  (('integrated circuit', 'pv'), 23),
#  (('food products', 'biofuel'), 23),
#  (('gas turbine', 'biofuel'), 23),
#  (('mobile robot', 'AI'), 23),
#  (('cluster', 'AI'), 23),
#  (('organic thin film', 'pv'), 23),
#  (('face recognition', 'AI'), 23),
#  (('photovoltaic module comprising', 'pv'), 23),
#  (('bio oil', 'biofuel'), 23),
#  (('machine learning system', 'AI'), 23),
#  (('process', 'AI'), 23),
#  (('lignin', 'biofuel'), 23),
#  (('organic thin film transistor', 'pv'), 23),
#  (('photovoltaic applications', 'pv'), 23),
#  (('nanowires', 'pv'), 23),
#  (('estimating', 'AI'), 23),
#  (('natural language', 'AI'), 23),
#  (('fullerene derivative', 'pv'), 23),
#  (('sun rays', 'thermal'), 22),
#  (('parabolic reflector', 'thermal'), 22),
#  (('radiant', 'thermal'), 22),
#  (('diffusion', 'pv'), 22),
#  (('substrate', 'thermal'), 22),
#  (('carrier substrate', 'pv'), 22),
#  (('insulating substrate', 'pv'), 22),
#  (('junctions', 'pv'), 22),
#  (('solar cell assembly', 'pv'), 22),
#  (('compound semiconductor', 'pv'), 22),
#  (('photovoltaic cell', 'thermal'), 22),
#  (('semiconductor film', 'pv'), 22),
#  (('fluorescent', 'pv'), 22),
#  (('absorption', 'pv'), 22),
#  (('detector', 'pv'), 22),
#  (('generate electricity', 'wind'), 22),
#  (('distillation', 'biofuel'), 22),
#  (('reducing', 'pv'), 22),
#  (('saccharomyces cerevisiae', 'biofuel'), 22),
#  (('wind power system', 'wind'), 22),
#  (('glucose', 'biofuel'), 22),
#  (('modules', 'thermal'), 22),
#  (('conductive layer', 'pv'), 22),
#  (('second neural network', 'AI'), 22),
#  (('power generation system', 'pv'), 22),
#  (('image retrieval', 'AI'), 22),
#  (('power converter', 'pv'), 22),
#  (('language model', 'AI'), 22),
#  (('learning system', 'AI'), 22),
#  (('sensitized solar cell', 'pv'), 22),
#  (('processing system', 'AI'), 22),
#  (('predictive models', 'AI'), 22),
#  (('alpha amylases', 'biofuel'), 22),
#  (('image stream', 'AI'), 22),
#  (('system method', 'AI'), 22),
#  (('fatty acid alkyl ester', 'biofuel'), 22),
#  (('formulations', 'pv'), 22),
#  (('segmentation', 'AI'), 22),
#  (('user device', 'AI'), 22),
#  (('organic photovoltaics', 'pv'), 22),
#  (('parallel', 'pv'), 21),
#  (('sea waves', 'sea'), 21),
#  (('heat transfer fluid', 'thermal'), 21),
#  (('anaerobic digestion process', 'waste'), 21),
#  (('rays', 'thermal'), 21),
#  (('heat storage', 'thermal'), 21),
#  (('solar collector comprises', 'thermal'), 21),
#  (('device', 'wind'), 21),
#  (('solar cell array', 'pv'), 21),
#  (('epitaxial layer', 'pv'), 21),
#  (('semiconductor materials', 'pv'), 21),
#  (('charcoal', 'biofuel'), 21),
#  (('solar cell electrodes', 'pv'), 21),
#  (('microorganism', 'biofuel'), 21),
#  (('plasma', 'pv'), 21),
#  (('fatty acid esters', 'biofuel'), 21),
#  (('manufacturing', 'wind'), 21),
#  (('photodiodes', 'pv'), 21),
#  (('annealing', 'pv'), 21),
#  (('semiconductor laminate member', 'pv'), 21),
#  (('zinc oxide', 'pv'), 21),
#  (('radiation detector', 'pv'), 21),
#  (('reactor', 'biofuel'), 21),
#  (('infrared photodetector', 'pv'), 21),
#  (('video data', 'AI'), 21),
#  (('light absorption layer', 'pv'), 21),
#  (('pv modules', 'thermal'), 21),
#  (('controller', 'pv'), 21),
#  (('audio data', 'AI'), 21),
#  (('nucleic acid sequence', 'biofuel'), 21),
#  (('reactive power', 'wind'), 21),
#  (('pixels', 'AI'), 21),
#  (('rules engine', 'AI'), 21),
#  (('language processing', 'AI'), 21),
#  (('triglyceride oils', 'biofuel'), 21),
#  (('lighting device', 'pv'), 21),
#  (('vehicle system', 'AI'), 21),
#  (('computing system', 'AI'), 21),
#  (('cadmium telluride', 'pv'), 20),
#  (('cellulosic materials', 'biofuel'), 20),
#  (('clamping', 'thermal'), 20),
#  (('data processing', 'AI'), 20),
#  (('solar power', 'thermal'), 20),
#  (('solar collector panel', 'thermal'), 20),
#  (('crystalline silicon', 'pv'), 20),
#  (('plurality', 'thermal'), 20),
#  (('conductivity', 'pv'), 20),
#  (('sails', 'wind'), 20),
#  (('adhesive', 'thermal'), 20),
#  (('solar energy collectors', 'thermal'), 20),
#  (('document', 'AI'), 20),
#  (('synchronous generator', 'wind'), 20),
#  (('electromagnetic radiation', 'pv'), 20),
#  (('structure', 'wind'), 20),
#  (('integrated circuits', 'pv'), 20),
#  (('drying', 'biofuel'), 20),
#  (('converter', 'pv'), 20),
#  (('fastening', 'thermal'), 20),
#  (('amorphous silicon film', 'pv'), 20),
#  (('automatic transmission', 'AI'), 20),
#  (('camera system', 'AI'), 20),
#  (('image capture', 'AI'), 20),
#  (('general formula', 'pv'), 20),
#  (('type dopant', 'pv'), 20),
#  (('forecasting', 'AI'), 20),
#  (('training', 'AI'), 20),
#  (('neural networks', 'AI'), 20),
#  (('light absorbing', 'pv'), 20),
#  (('dopant', 'pv'), 20),
#  (('quantum dot layer', 'pv'), 20),
#  (('data mining', 'AI'), 20),
#  (('optoelectronic component', 'pv'), 20),
#  (('network', 'AI'), 20),
#  (('contextual information', 'AI'), 20),
#  (('oleds', 'pv'), 20),
#  (('texturing', 'pv'), 20),
#  (('wind turbine generators', 'wind'), 20),
#  (('energy storage', 'pv'), 20),
#  (('syngas', 'biofuel'), 20),
#  (('carbon dioxide', 'biofuel'), 20),
#  (('compressed air energy storage system', 'wind'), 20),
#  (('microbial fermentation', 'biofuel'), 20),
#  (('cameras', 'AI'), 20),
#  (('cardiovascular information', 'AI'), 20),
#  (('water wheel', 'hydro'), 19),
#  (('vertical axis windmill', 'wind'), 19),
#  (('conduit', 'thermal'), 19),
#  (('multi layer', 'pv'), 19),
#  (('optical character recognition', 'AI'), 19),
#  (('solar collector assembly', 'thermal'), 19),
#  (('chemical vapor deposition', 'pv'), 19),
#  (('electric generator', 'sea'), 19),
#  (('fabrication', 'pv'), 19),
#  (('electrolyte', 'pv'), 19),
#  (('waste water', 'waste'), 19),
#  (('transparent conductive layer', 'pv'), 19),
#  (('power generation', 'hydro'), 19),
#  (('fermentation', 'waste'), 19),
#  (('power', 'wind'), 19),
#  (('assembly', 'thermal'), 19),
#  (('coupling', 'thermal'), 19),
#  (('anaerobic', 'waste'), 19),
#  (('orientation', 'AI'), 19),
#  (('display panel', 'pv'), 19),
#  (('refractive index', 'pv'), 19),
#  (('quantum well', 'pv'), 19),
#  (('reflective', 'pv'), 19),
#  (('si substrate', 'pv'), 19),
#  (('imaging device', 'pv'), 19),
#  (('fatty acids', 'biofuel'), 19),
#  (('first substrate', 'pv'), 19),
#  (('feedstock', 'biofuel'), 19),
#  (('biomass material', 'biofuel'), 19),
#  (('processing apparatus', 'AI'), 19),
#  (('analyze', 'AI'), 19),
#  (('counter electrode', 'pv'), 19),
#  (('power conditioning unit', 'pv'), 19),
#  (('management system', 'AI'), 19),
#  (('audio', 'AI'), 19),
#  (('cellulolytic enhancing activity', 'biofuel'), 19),
#  (('carbon alcohols', 'biofuel'), 19),
#  (('isobutanol biosynthetic pathway', 'biofuel'), 19),
#  (('solar cell element', 'pv'), 19),
#  (('reversible mechanism', 'wind'), 19),
#  (('computer programs', 'AI'), 19),
#  (('energy storage system', 'pv'), 19),
#  (('junction', 'pv'), 18),
#  (('heat collecting', 'thermal'), 18),
#  (('solar rays', 'thermal'), 18),
#  (('pattern', 'pv'), 18),
#  (('energy collector', 'thermal'), 18),
#  (('electrical energy', 'pv'), 18),
#  (('sheet', 'pv'), 18),
#  (('electrical energy', 'sea'), 18),
#  (('hydro', 'hydro'), 18),
#  (('infrared detector', 'pv'), 18),
#  (('alternator', 'wind'), 18),
#  (('generating energy', 'sea'), 18),
#  (('wavelength', 'pv'), 18),
#  (('bioreactor', 'waste'), 18),
#  (('butanol', 'biofuel'), 18),
#  (('photosensor', 'pv'), 18),
#  (('transparent conductor', 'pv'), 18),
#  (('barrier layer', 'pv'), 18),
#  (('production method', 'pv'), 18),
#  (('glass', 'pv'), 18),
#  (('composition', 'biofuel'), 18),
#  (('neuron', 'AI'), 18),
#  (('emitting diode', 'pv'), 18),
#  (('pattern matching', 'AI'), 18),
#  (('combustion', 'biofuel'), 18),
#  (('pretreated biomass', 'biofuel'), 18),
#  (('polysilicon', 'pv'), 18),
#  (('speech', 'AI'), 18),
#  (('electrode comprising', 'pv'), 18),
#  (('substrate layer', 'pv'), 18),
#  (('waste biomass', 'biofuel'), 18),
#  (('glass substrates', 'pv'), 18),
#  (('opto electronic device', 'pv'), 18),
#  (('monitoring', 'pv'), 18),
#  (('software', 'AI'), 18),
#  (('plastic substrate', 'pv'), 18),
#  (('power conversion system', 'pv'), 18),
#  (('vehicles', 'AI'), 18),
#  (('nanostructures', 'pv'), 18),
#  (('utility grid', 'pv'), 18),
#  (('stator arrangement', 'wind'), 18),
#  (('fermentation products', 'biofuel'), 18),
#  (('implementations', 'AI'), 18),
#  (('bracket', 'thermal'), 18),
#  (('host cells', 'biofuel'), 18),
#  (('example method', 'AI'), 18),
#  (('rule engine', 'AI'), 18),
#  (('ink', 'pv'), 18),
#  (('machine learning models', 'AI'), 18),
#  (('crystalline silicon substrate', 'pv'), 18),
#  (('object detector', 'AI'), 18),
#  (('transparent conductive oxide layer', 'pv'), 18),
#  (('algal biomass', 'biofuel'), 18),
#  (('spike timing dependent plasticity', 'AI'), 18),
#  (('selective extraction', 'biofuel'), 18),
#  (('fuel feed stocks', 'biofuel'), 18),
#  (('msw waste streams', 'biofuel'), 18),
#  (('memory device', 'AI'), 18),
#  (('glass frit', 'pv'), 18),
#  (('image classification', 'AI'), 18),
#  (('cloud', 'AI'), 18),
#  (('video content', 'AI'), 18),
#  (('boiler', 'thermal'), 17),
#  (('reflective surfaces', 'thermal'), 17),
#  (('reflective layer', 'pv'), 17),
#  (('oxide layer', 'pv'), 17),
#  (('solar heating panel', 'thermal'), 17),
#  (('solar heating apparatus', 'thermal'), 17),
#  (('junction solar cells', 'pv'), 17),
#  (('buoy', 'sea'), 17),
#  (('focusing', 'thermal'), 17),
#  (('mechanism', 'thermal'), 17),
#  (('generating electricity', 'sea'), 17),
#  (('solar collector system', 'thermal'), 17),
#  (('generator', 'thermal'), 17),
#  (('wind turbine apparatus', 'wind'), 17),
#  (('silicon wafers', 'pv'), 17),
#  (('fresnel lens', 'thermal'), 17),
#  (('supports', 'thermal'), 17),
#  (('laser', 'pv'), 17),
#  (('electric machine', 'wind'), 17),
#  (('axis wind turbine', 'wind'), 17),
#  (('band gap', 'pv'), 17),
#  (('type layer', 'pv'), 17),
#  (('transparent electrode layer', 'pv'), 17),
#  (('photovoltaic array', 'pv'), 17),
#  (('torrefaction', 'biofuel'), 17),
#  (('lattice', 'pv'), 17),
#  (('yeast cells', 'biofuel'), 17),
#  (('substrate comprises', 'pv'), 17),
#  (('semiconductor structure', 'pv'), 17),
#  (('neural network system', 'AI'), 17),
#  (('resolution', 'AI'), 17),
#  (('photovoltaic systems', 'pv'), 17),
#  (('securing', 'thermal'), 17),
#  (('hydroelectric turbine', 'hydro'), 17),
#  (('monitoring system', 'AI'), 17),
#  (('behavior', 'AI'), 17),
#  (('wind power generation system', 'wind'), 17),
#  (('generation system', 'pv'), 17),
#  (('esterification', 'biofuel'), 17),
#  (('sealing', 'pv'), 17),
#  (('airflow', 'wind'), 17),
#  (('organic field effect transistors', 'pv'), 17),
#  (('flexible organic light', 'pv'), 17),
#  (('permanent magnets', 'wind'), 17),
#  (('wind turbine generator system', 'wind'), 17),
#  (('support vector machines', 'AI'), 17),
#  (('modeling', 'AI'), 17),
#  (('novel polymers', 'pv'), 17),
#  (('thickness', 'pv'), 17),
#  (('nucleic acids', 'biofuel'), 17),
#  (('diesel fuel', 'biofuel'), 17),
#  (('paste composition', 'pv'), 17),
#  (('knowledge', 'AI'), 17),
#  (('managing', 'AI'), 17),
#  (('semiconductor nanocrystals', 'pv'), 17),
#  (('light trapping', 'pv'), 17),
#  (('video', 'AI'), 17),
#  (('biomass comprises', 'biofuel'), 17),
#  (('object tracking', 'AI'), 17),
#  (('training image', 'AI'), 17),
#  (('polyester film', 'pv'), 17),
#  (('learning model', 'AI'), 17),
#  (('pitch system', 'wind'), 17),
#  (('automatic speech recognition asr', 'AI'), 17),
#  (('robotic device', 'AI'), 17),
#  (('efficient fact', 'AI'), 17),
#  (('information processes', 'AI'), 17),
#  (('qa system', 'AI'), 17),
#  (('solar energy absorber', 'thermal'), 16),
#  (('heating system', 'thermal'), 16),
#  (('insulating', 'thermal'), 16),
#  (('mirrors', 'thermal'), 16),
#  (('infrared radiation', 'pv'), 16),
#  (('power generating apparatus', 'wind'), 16),
#  (('otec system', 'sea'), 16),
#  (('controlling', 'thermal'), 16),
#  (('generating electricity', 'hydro'), 16),
#  (('rotatable', 'wind'), 16),
#  (('flows', 'hydro'), 16),
#  (('heat collector', 'thermal'), 16),
#  (('efficiency', 'thermal'), 16),
#  (('reflection coating', 'pv'), 16),
#  (('mechanism', 'wind'), 16),
#  (('turbine wheel', 'hydro'), 16),
#  (('cadmium sulfide', 'pv'), 16),
#  (('invention', 'sea'), 16),
#  (('patterns', 'pv'), 16),
#  (('optical system', 'thermal'), 16),
#  (('first conductivity type', 'pv'), 16),
#  (('roof structure', 'thermal'), 16),
#  (('silicon nitride', 'pv'), 16),
#  (('pn junctions', 'pv'), 16),
#  (('methane production', 'waste'), 16),
#  (('cdte', 'pv'), 16),
#  (('single crystal', 'pv'), 16),
#  (('copper', 'pv'), 16),
#  (('induction generator', 'wind'), 16),
#  (('slurry', 'biofuel'), 16),
#  (('solar array', 'thermal'), 16),
#  (('silicon layer', 'pv'), 16),
#  (('heliostats', 'thermal'), 16),
#  (('anaerobic fermentation', 'waste'), 16),
#  (('intermediate layer', 'pv'), 16),
#  (('fuel composition', 'biofuel'), 16),
#  (('coupling', 'wind'), 16),
#  (('single crystal semiconductor layer', 'pv'), 16),
#  (('thin film photovoltaic devices', 'pv'), 16),
#  (('solar concentrator', 'pv'), 16),
#  (('sampling', 'AI'), 16),
#  (('separating', 'biofuel'), 16),
#  (('alcohol dehydrogenase', 'biofuel'), 16),
#  (('rotor assembly', 'wind'), 16),
#  (('neural network model', 'AI'), 16),
#  (('fermentation medium', 'biofuel'), 16),
#  (('neurons', 'AI'), 16),
#  (('categorizing', 'AI'), 16),
#  (('gallium nitride', 'pv'), 16),
#  (('solar cell module', 'thermal'), 16),
#  (('foil', 'pv'), 16),
#  (('patient data', 'AI'), 16),
#  (('lignocellulose', 'biofuel'), 16),
#  (('solar power generation', 'pv'), 16),
#  (('engine', 'AI'), 16),
#  (('organic semiconductors', 'pv'), 16),
#  (('parent termamyl', 'biofuel'), 16),
#  (('transformer', 'wind'), 16),
#  (('optimization', 'AI'), 16),
#  (('reactive', 'wind'), 16),
#  (('oled display', 'pv'), 16),
#  (('wind turbine controller', 'wind'), 16),
#  (('method system', 'AI'), 16),
#  (('algorithm', 'AI'), 16),
#  (('validating', 'AI'), 16),
#  (('search results', 'AI'), 16),
#  (('printable semiconductor elements', 'pv'), 16),
#  (('conversion layer', 'pv'), 16),
#  (('transporting', 'wind'), 16),
#  (('aspect', 'pv'), 16),
#  (('wind turbine component', 'wind'), 16),
#  (('algae', 'biofuel'), 16),
#  (('information processing device', 'AI'), 16),
#  (('organic layer', 'pv'), 16),
#  (('wind power turbine', 'wind'), 16),
#  (('capturing', 'AI'), 16),
#  (('machine learning engine', 'AI'), 16),
#  (('micro inverter', 'pv'), 16),
#  (('organic photoelectric device', 'pv'), 16),
#  (('compositions', 'waste'), 16),
#  (('graphene layer', 'pv'), 16),
#  (('particular organic electroluminescent devices', 'pv'), 16),
#  (('image capture device', 'AI'), 16),
#  (('computer storage media', 'AI'), 16),
#  (('cnn', 'AI'), 16),
#  (('deep learning model', 'AI'), 16),
#  (('process', 'thermal'), 15),
#  (('power generation', 'thermal'), 15),
#  (('generators', 'hydro'), 15),
#  (('wind machine', 'wind'), 15),
#  (('photodetector device', 'pv'), 15),
#  (('solar absorber', 'thermal'), 15),
#  (('incident light', 'pv'), 15),
#  (('schottky barrier', 'pv'), 15),
#  (('systems', 'thermal'), 15),
#  (('methane fermentation', 'waste'), 15),
#  (('ion implantation', 'pv'), 15),
#  (('generating', 'pv'), 15),
#  (('flexible', 'thermal'), 15),
#  (('power generator', 'hydro'), 15),
#  (('tracking system', 'thermal'), 15),
#  ...]

# %%
sorted_edge_weights
# Out:
# [((('expert system', 'AI'), ('wind turbine', 'wind')), 252.07767096779605),
#  ((('adaptive control', 'AI'), ('wind turbine', 'wind')), 165.7536164683794),
#  ((('wind turbine', 'AI'), ('wind turbine', 'wind')), 164.23044556800096),
#  ((('neural network', 'AI'), ('wind turbine', 'wind')), 150.90384552665128),
#  ((('power generator speed', 'AI'), ('wind turbine', 'wind')),
#   144.9066055679999),
#  ((('automatic transmission', 'AI'), ('wind turbine', 'wind')),
#   135.2134188393425),
#  ((('fuzzy reasoning', 'AI'), ('wind turbine', 'wind')), 118.00058296319894),
#  ((('fuzzy set theory', 'AI'), ('wind turbine', 'wind')), 110.29885443587976),
#  ((('pattern recognition', 'AI'), ('wind turbine', 'wind')),
#   106.95644114734088),
#  ((('expert system', 'AI'), ('solar cell', 'pv')), 99.61504094896097),
#  ((('pattern recognition apparatus', 'AI'), ('wind turbine', 'wind')),
#   97.54663162075477),
#  ((('probabilistic learning element', 'AI'), ('wind turbine', 'wind')),
#   96.02192405938088),
#  ((('fuzzy production rules', 'AI'), ('wind turbine', 'wind')),
#   84.65731727523774),
#  ((('pattern recognition', 'AI'), ('solar cell', 'pv')), 74.9201880944148),
#  ((('fuzzy logic controller', 'AI'), ('wind turbine', 'wind')),
#   74.53637618073563),
#  ((('automatic transmissions', 'AI'), ('wind turbine', 'wind')),
#   73.16287856639944),
#  ((('pattern recognition apparatus', 'AI'), ('solar cell', 'pv')),
#   63.08968903999479),
#  ((('gear ratio', 'AI'), ('wind turbine', 'wind')), 62.22138175143889),
#  ((('neural network', 'AI'), ('solar cell', 'pv')), 60.74366990008288),
#  ((('robot arm', 'AI'), ('wind turbine', 'wind')), 59.11289200793988),
#  ((('learned state sequence', 'AI'), ('wind turbine', 'wind')),
#   58.84798327013321),
#  ((('actuator inputs', 'AI'), ('wind turbine', 'wind')), 56.8469270568958),
#  ((('learns', 'AI'), ('wind turbine', 'wind')), 56.8469270568958),
#  ((('expert system', 'AI'), ('substrate', 'pv')), 56.50294344302571),
#  ((('controllable variable', 'AI'), ('wind turbine', 'wind')),
#   56.43629088767982),
#  ((('compensating', 'AI'), ('wind turbine', 'wind')), 56.43629088767982),
#  ((('expert system', 'AI'), ('inverter', 'pv')), 55.73692923494396),
#  ((('diagnostic expert system', 'AI'), ('wind turbine', 'wind')),
#   54.76799548257705),
#  ((('optical character recognition', 'AI'), ('wind turbine', 'wind')),
#   54.684808955736415),
#  ((('clutch control pattern', 'AI'), ('wind turbine', 'wind')),
#   53.8625635482008),
#  ((('faults', 'AI'), ('wind turbine', 'wind')), 52.85910198435814),
#  ((('automatic transmission control system', 'AI'), ('wind turbine', 'wind')),
#   52.802932285439816),
#  ((('vehicle speed', 'AI'), ('wind turbine', 'wind')), 52.802932285439816),
#  ((('pattern recognition', 'AI'), ('substrate', 'pv')), 51.41491883458533),
#  ((('expert driver', 'AI'), ('wind turbine', 'wind')), 49.86429495459796),
#  ((('neural network', 'AI'), ('inverter', 'pv')), 49.5347467508121),
#  ((('optical character recognition', 'AI'), ('solar cell', 'pv')),
#   46.496980617500476),
#  ((('diagnostic system', 'AI'), ('wind turbine', 'wind')), 46.054198274457384),
#  ((('sensing', 'AI'), ('wind turbine', 'wind')), 44.83985109811168),
#  ((('shift control system', 'AI'), ('wind turbine', 'wind')),
#   43.61323325865948),
#  ((('unsupervised learning', 'AI'), ('wind turbine', 'wind')),
#   43.383363172761165),
#  ((('expert system', 'AI'), ('photovoltaic device', 'pv')), 43.09528432803814),
#  ((('recognition', 'AI'), ('wind turbine', 'wind')), 40.97319794284878),
#  ((('recognition', 'AI'), ('solar cell', 'pv')), 40.24498030660466),
#  ((('expert system techniques', 'AI'), ('wind turbine', 'wind')),
#   40.180711891244975),
#  ((('communications system', 'AI'), ('wind turbine', 'wind')),
#   40.180711891244975),
#  ((('failures', 'AI'), ('wind turbine', 'wind')), 40.180711891244975),
#  ((('input signals', 'AI'), ('wind turbine', 'wind')), 39.602082802728596),
#  ((('organizing', 'AI'), ('wind turbine', 'wind')), 39.602082802728596),
#  ((('circuits', 'AI'), ('wind turbine', 'wind')), 39.602082802728596),
#  ((('decision tree', 'AI'), ('wind turbine', 'wind')), 39.05597683482572),
#  ((('independent sequential pattern recognition device', 'AI'),
#    ('wind turbine', 'wind')),
#   38.399457818050244),
#  ((('inference engine', 'AI'), ('wind turbine', 'wind')), 38.11228424847316),
#  ((('motor vehicle comprises', 'AI'), ('wind turbine', 'wind')),
#   37.854059913215714),
#  ((('positional information', 'AI'), ('wind turbine', 'wind')),
#   37.17394078924763),
#  ((('memory', 'AI'), ('wind turbine', 'wind')), 37.17394078924763),
#  ((('expert system', 'AI'), ('controlling', 'wind')), 36.91539999277022),
#  ((('pattern recognition apparatus', 'AI'), ('substrate', 'pv')),
#   36.772977226382956),
#  ((('failure mode schema', 'AI'), ('wind turbine', 'wind')),
#   36.551540382105415),
#  ((('independent diagnostic problem solver', 'AI'), ('wind turbine', 'wind')),
#   36.551540382105415),
#  ((('hierarchy', 'AI'), ('wind turbine', 'wind')), 36.551540382105415),
#  ((('throttle valve', 'AI'), ('wind turbine', 'wind')), 35.93895582891978),
#  ((('process sensors', 'AI'), ('wind turbine', 'wind')), 35.88740149247981),
#  ((('etcher machine state', 'AI'), ('wind turbine', 'wind')),
#   35.88740149247981),
#  ((('gearshift', 'AI'), ('wind turbine', 'wind')), 34.79302232063964),
#  ((('vehicle response', 'AI'), ('wind turbine', 'wind')), 34.79302232063964),
#  ((('classification', 'AI'), ('wind turbine', 'wind')), 34.43241461995905),
#  ((('neural network', 'AI'), ('substrate', 'pv')), 33.9956173725692),
#  ((('process control', 'AI'), ('wind turbine', 'wind')), 33.178668933119816),
#  ((('pattern recognition', 'AI'), ('photovoltaic device', 'pv')),
#   33.03790082260928),
#  ((('robot', 'AI'), ('wind turbine', 'wind')), 32.309199222275566),
#  ((('expert system', 'AI'), ('wind turbine generator', 'wind')),
#   32.069292712427),
#  ((('control system', 'AI'), ('wind turbine', 'wind')), 32.03973288345569),
#  ((('internal combustion engine', 'AI'), ('wind turbine', 'wind')),
#   31.497507305127783),
#  ((('modification unit', 'AI'), ('wind turbine', 'wind')), 31.32278200319985),
#  ((('thermal power', 'AI'), ('wind turbine', 'wind')), 31.32278200319985),
#  ((('expert system', 'AI'), ('power system', 'pv')), 30.671906881535975),
#  ((('orientation', 'AI'), ('wind turbine', 'wind')), 30.61228713565168),
#  ((('neural network', 'AI'), ('photovoltaic device', 'pv')),
#   30.264101669338814),
#  ((('probabilistic learning element', 'AI'), ('solar cell', 'pv')),
#   30.09016702549962),
#  ((('automatic test system', 'AI'), ('wind turbine', 'wind')),
#   29.618232953241314),
#  ((('ftp data', 'AI'), ('wind turbine', 'wind')), 29.618232953241314),
#  ((('ai data processor', 'AI'), ('wind turbine', 'wind')), 29.618232953241314),
#  ((('recognition apparatus', 'AI'), ('wind turbine', 'wind')),
#   29.56399531130841),
#  ((('speech analysis unit', 'AI'), ('wind turbine', 'wind')),
#   28.66985899130843),
#  ((('discrimination processing', 'AI'), ('wind turbine', 'wind')),
#   28.66985899130843),
#  ((('control unit', 'AI'), ('wind turbine', 'wind')), 28.123159125196697),
#  ((('exhaust gas constituents', 'AI'), ('wind turbine', 'wind')),
#   28.123159125196697),
#  ((('optical character recognition', 'AI'), ('substrate', 'pv')),
#   28.087965008186103),
#  ((('data pointers', 'AI'), ('wind turbine', 'wind')), 27.83988270268393),
#  ((('line process control', 'AI'), ('wind turbine', 'wind')),
#   27.83988270268393),
#  ((('automotive vehicle', 'AI'), ('wind turbine', 'wind')),
#   27.352431931391582),
#  ((('basic fuzzy set theory rule', 'AI'), ('wind turbine', 'wind')),
#   26.897726252482336),
#  ((('calculated overall satisfaction degrees', 'AI'),
#    ('wind turbine', 'wind')),
#   26.897726252482336),
#  ((('output array patterns', 'AI'), ('wind turbine', 'wind')),
#   26.530260864859763),
#  ((('amplifiers', 'AI'), ('wind turbine', 'wind')), 26.530260864859763),
#  ((('real time', 'AI'), ('wind turbine', 'wind')), 26.497397739847305),
#  ((('layered neural network', 'AI'), ('wind turbine', 'wind')),
#   26.446761352396567),
#  ((('neural net', 'AI'), ('wind turbine', 'wind')), 26.17330098585584),
#  ((('light detector', 'AI'), ('wind turbine', 'wind')), 26.115797924904633),
#  ((('projector', 'AI'), ('wind turbine', 'wind')), 26.115797924904633),
#  ((('expert system', 'AI'), ('photovoltaic cell', 'pv')), 26.08325458329587),
#  ((('centroid', 'AI'), ('wind turbine', 'wind')), 25.97219059433435),
#  ((('flat object', 'AI'), ('wind turbine', 'wind')), 25.92314580713435),
#  ((('artificial intelligence', 'AI'), ('wind turbine', 'wind')),
#   25.666539503615727),
#  ((('pattern recognition apparatus', 'AI'), ('photovoltaic device', 'pv')),
#   25.567121291673246),
#  ((('elevator trouble', 'AI'), ('wind turbine', 'wind')), 25.349156596776684),
#  ((('interactive initialization procedure', 'AI'), ('wind turbine', 'wind')),
#   25.349156596776684),
#  ((('video informatin', 'AI'), ('wind turbine', 'wind')), 25.311810027847322),
#  ((('coarse information', 'AI'), ('wind turbine', 'wind')),
#   25.311810027847322),
#  ((('neural network architecture', 'AI'), ('wind turbine', 'wind')),
#   25.20075058790384),
#  ((('training input', 'AI'), ('wind turbine', 'wind')), 25.136672654131015),
#  ((('operation mode', 'AI'), ('wind turbine', 'wind')), 25.136672654131015),
#  ((('regulatory controller', 'AI'), ('wind turbine', 'wind')),
#   25.136672654131015),
#  ((('expert system', 'AI'), ('generator', 'wind')), 25.111840333823736),
#  ((('priority number', 'AI'), ('wind turbine', 'wind')), 24.919566928182963),
#  ((('training examples', 'AI'), ('wind turbine', 'wind')), 24.851587608575766),
#  ((('recognition', 'AI'), ('substrate', 'pv')), 24.7586364764649),
#  ((('fault isolation procedure', 'AI'), ('wind turbine', 'wind')),
#   24.43582914969579),
#  ((('terminal detects vehicle malfunctions', 'AI'), ('wind turbine', 'wind')),
#   24.43582914969579),
#  ((('fsp', 'AI'), ('wind turbine', 'wind')), 24.43582914969579),
#  ((('genetic algorithm', 'AI'), ('wind turbine', 'wind')), 24.43022939160548),
#  ((('registers', 'AI'), ('wind turbine', 'wind')), 24.33868646842324),
#  ((('neural network controller', 'AI'), ('wind turbine', 'wind')),
#   24.33069173145586),
#  ((('expert system', 'AI'), ('power grid', 'pv')), 24.287903723519747),
#  ((('data processing', 'AI'), ('wind turbine', 'wind')), 24.15021414432725),
#  ((('instruction unit', 'AI'), ('wind turbine', 'wind')), 24.15021414432725),
#  ((('expert system', 'AI'), ('grid', 'pv')), 24.072533173370818),
#  ((('wind turbine', 'AI'), ('wind turbine generator', 'wind')), 23.77172736),
#  ((('adaptive', 'AI'), ('wind turbine', 'wind')), 23.704708276223815),
#  ((('feature', 'AI'), ('wind turbine', 'wind')), 23.67342612725734),
#  ((('reference patterns', 'AI'), ('wind turbine', 'wind')),
#   23.453659934922804),
#  ((('cylinder pressure signal', 'AI'), ('wind turbine', 'wind')),
#   23.267407527935866),
#  ((('variable automatic transmission', 'AI'), ('wind turbine', 'wind')),
#   23.03935983009769),
#  ((('pattern recognition', 'AI'), ('manufacturing', 'pv')),
#   22.977861206998746),
#  ((('image pattern data', 'AI'), ('wind turbine', 'wind')),
#   22.976335886745392),
#  ((('second correlation', 'AI'), ('wind turbine', 'wind')),
#   22.976335886745392),
#  ((('pattern recognition', 'AI'), ('photovoltaic cell', 'pv')),
#   22.82977415725038),
#  ((('neural network', 'AI'), ('grid', 'pv')), 22.720523673599953),
#  ((('character recognition', 'AI'), ('wind turbine', 'wind')),
#   22.695771385805667),
#  ((('character recognition', 'AI'), ('solar cell', 'pv')), 22.47362697520717),
#  ((('vibration control', 'AI'), ('wind turbine', 'wind')), 22.24972578815988),
#  ((('expert system', 'AI'), ('lighting device', 'pv')), 22.104780152831964),
#  ((('general purpose expert system architecture', 'AI'),
#    ('wind turbine', 'wind')),
#   22.082316123340693),
#  ((('individual machines', 'AI'), ('wind turbine', 'wind')),
#   22.082316123340693),
#  ((('vibration data', 'AI'), ('wind turbine', 'wind')), 22.082316123340693),
#  ((('predicted output', 'AI'), ('wind turbine', 'wind')), 22.0286573567999),
#  ((('neural network', 'AI'), ('controlling', 'wind')), 22.02551486300147),
#  ((('neural network', 'AI'), ('wind turbine generator', 'wind')),
#   21.92648607586705),
#  ((('digital circuitry', 'AI'), ('wind turbine', 'wind')), 21.880133627903874),
#  ((('adaptive control', 'AI'), ('wind turbine generator', 'wind')),
#   21.85586565119998),
#  ((('expert system', 'AI'), ('manufacturing', 'pv')), 21.85014293544941),
#  ((('neural network', 'AI'), ('power system', 'pv')), 21.684435664895997),
#  ((('cytological specimen classification', 'AI'), ('wind turbine', 'wind')),
#   21.55122771148783),
#  ((('automated microscope', 'AI'), ('wind turbine', 'wind')),
#   21.55122771148783),
#  ((('screening system', 'AI'), ('wind turbine', 'wind')), 21.55122771148783),
#  ((('general purpose pattern recognition method', 'AI'),
#    ('wind turbine', 'wind')),
#   21.497900890521418),
#  ((('expert system', 'AI'), ('wind energy', 'wind')), 21.161871964569446),
#  ((('dimensional coulomb network', 'AI'), ('wind turbine', 'wind')),
#   21.12853002485747),
#  ((('multi layer', 'AI'), ('wind turbine', 'wind')), 21.12853002485747),
#  ((('learned state sequence', 'AI'), ('solar cell', 'pv')), 21.07506499485682),
#  ((('expert system', 'AI'), ('isolation', 'pv')), 20.898544693248013),
#  ((('control process', 'AI'), ('wind turbine', 'wind')), 20.89684973371378),
#  ((('new rules', 'AI'), ('wind turbine', 'wind')), 20.89684973371378),
#  ((('expert system', 'AI'), ('photovoltaic diodes', 'pv')), 20.88814694399998),
#  ((('crosswind', 'AI'), ('wind turbine', 'wind')), 20.76962566216071),
#  ((('observed spectral features', 'AI'), ('wind turbine', 'wind')),
#   20.76962566216071),
#  ((('optical device', 'AI'), ('wind turbine', 'wind')), 20.76962566216071),
#  ((('reference patterns', 'AI'), ('solar cell', 'pv')), 20.707928636129118),
#  ((('expert system', 'AI'), ('monitoring', 'wind')), 20.66132494172155),
#  ((('ann controller', 'AI'), ('wind turbine', 'wind')), 20.55412181237748),
#  ((('ann block output', 'AI'), ('wind turbine', 'wind')), 20.55412181237748),
#  ((('pattern recognition', 'AI'), ('inverter', 'pv')), 20.48737679592647),
#  ((('independent sequential pattern recognition', 'AI'),
#    ('wind turbine', 'wind')),
#   20.448525452083064),
#  ((('continuous process', 'AI'), ('wind turbine', 'wind')),
#   20.443620188159915),
#  ((('neural network', 'AI'), ('ion implantation', 'pv')), 20.385216),
#  ((('genetic algorithm', 'AI'), ('solar cell', 'pv')), 20.313972456652788),
#  ((('active control system', 'AI'), ('wind turbine', 'wind')),
#   20.276080127999982),
#  ((('automotive', 'AI'), ('wind turbine', 'wind')), 20.276080127999982),
#  ((('real time', 'AI'), ('solar cell', 'pv')), 20.21265945811343),
#  ((('neural network', 'AI'), ('plasma region', 'pv')), 20.208959999999998),
#  ((('video informatin', 'AI'), ('solar cell', 'pv')), 20.11934745811343),
#  ((('coarse information', 'AI'), ('solar cell', 'pv')), 20.11934745811343),
#  ((('adaptive control', 'AI'), ('controlling', 'wind')), 20.067403161599994),
#  ((('process control system', 'AI'), ('wind turbine', 'wind')),
#   19.985656460083135),
#  ((('pattern', 'AI'), ('wind turbine', 'wind')), 19.95411479976325),
#  ((('expert system', 'AI'), ('photovoltaic system', 'pv')),
#   19.938768411525054),
#  ((('wind turbine', 'AI'), ('controlling', 'wind')), 19.869849599999995),
#  ((('segmentation features', 'AI'), ('wind turbine', 'wind')),
#   19.859392937557907),
#  ((('image preprocessor', 'AI'), ('wind turbine', 'wind')),
#   19.859392937557907),
#  ((('digital scan line signals', 'AI'), ('wind turbine', 'wind')),
#   19.859392937557907),
#  ((('data learning capability', 'AI'), ('wind turbine', 'wind')),
#   19.848789503999924),
#  ((('expert system', 'AI'), ('photodetector waveguide structures', 'pv')),
#   19.816482815999997),
#  ((('expert system', 'AI'), ('sti', 'pv')), 19.816482815999997),
#  ((('orientation', 'AI'), ('solar cell', 'pv')), 19.747146002595702),
#  ((('tower strike', 'AI'), ('wind turbine', 'wind')), 19.323839999999986),
#  ((('pattern recognition apparatus', 'AI'), ('inverter', 'pv')),
#   19.173708275613667),
#  ((('expert system', 'AI'), ('semiconductor dies', 'pv')), 19.12638873599998),
#  ((('secondary features', 'AI'), ('wind turbine', 'wind')),
#   18.986311735688492),
#  ((('power generator speed', 'AI'), ('wind turbine generator', 'wind')),
#   18.904527359999992),
#  ((('artificial neural network', 'AI'), ('wind turbine', 'wind')),
#   18.666787606364093),
#  ((('learning process', 'AI'), ('wind turbine', 'wind')), 18.663093743615956),
#  ((('expert system', 'AI'), ('wind power plant', 'wind')), 18.644701143859177),
#  ((('optical character recognition', 'AI'), ('photovoltaic device', 'pv')),
#   18.561953641235622),
#  ((('chinese characters', 'AI'), ('solar cell', 'pv')), 18.546023451819966),
#  ((('personal driving characteristics detecting means', 'AI'),
#    ('wind turbine', 'wind')),
#   18.473566150655945),
#  ((('generalized intelligence base', 'AI'), ('wind turbine', 'wind')),
#   18.473566150655945),
#  ((('individual expert', 'AI'), ('wind turbine', 'wind')), 18.453895262207944),
#  ((('combinatory situations', 'AI'), ('wind turbine', 'wind')),
#   18.453895262207944),
#  ((('medical diagnosis', 'AI'), ('wind turbine', 'wind')), 18.453895262207944),
#  ((('expert system', 'AI'), ('ion implantation', 'pv')), 18.439487999999994),
#  ((('expert system', 'AI'), ('plasma region', 'pv')), 18.439487999999994),
#  ((('network test manager', 'AI'), ('wind turbine', 'wind')),
#   18.40541470300563),
#  ((('pattern recognition', 'AI'), ('isolation', 'pv')), 18.387624098856953),
#  ((('automatic transmission', 'AI'), ('wind turbine generator', 'wind')),
#   18.326510787133383),
#  ((('expert system', 'AI'), ('photovoltaic panel', 'pv')), 18.152184117657555),
#  ((('neural network', 'AI'), ('photovoltaic cell', 'pv')), 18.123815856537515),
#  ((('symptom diagnostic rules', 'AI'), ('wind turbine', 'wind')),
#   18.041482255564773),
#  ((('segmentation features', 'AI'), ('solar cell', 'pv')), 18.022150937640912),
#  ((('image preprocessor', 'AI'), ('solar cell', 'pv')), 18.022150937640912),
#  ((('digital scan line signals', 'AI'), ('solar cell', 'pv')),
#   18.022150937640912),
#  ((('expert system', 'AI'), ('gel suspension', 'pv')), 17.994700799999983),
#  ((('operating system', 'AI'), ('wind turbine', 'wind')), 17.963677629127005),
#  ((('processing test measurements', 'AI'), ('wind turbine', 'wind')),
#   17.857552895999987),
#  ((('classifiers', 'AI'), ('wind turbine', 'wind')), 17.857552895999987),
#  ((('diagnostic purposes', 'AI'), ('wind turbine', 'wind')),
#   17.857552895999987),
#  ((('synapse structure', 'AI'), ('wind turbine', 'wind')), 17.848981020671967),
#  ((('processing speed', 'AI'), ('wind turbine', 'wind')), 17.848981020671967),
#  ((('probabilistic learning element', 'AI'), ('substrate', 'pv')),
#   17.82625913428372),
#  ((('inspection features', 'AI'), ('wind turbine', 'wind')),
#   17.760797392895967),
#  ((('rapid design system', 'AI'), ('wind turbine', 'wind')),
#   17.760797392895967),
#  ((('test image signals', 'AI'), ('wind turbine', 'wind')),
#   17.754425249955776),
#  ((('luminance level', 'AI'), ('wind turbine', 'wind')), 17.754425249955776),
#  ((('actuators', 'AI'), ('wind turbine', 'wind')), 17.74015588004658),
#  ((('classifier', 'AI'), ('wind turbine', 'wind')), 17.647747184885713),
#  ((('emission signals', 'AI'), ('wind turbine', 'wind')), 17.644360906506222),
#  ((('adaptive neural processing', 'AI'), ('wind turbine', 'wind')),
#   17.644360906506222),
#  ((('prognosticate futur', 'AI'), ('wind turbine', 'wind')),
#   17.644360906506222),
#  ((('recognition', 'AI'), ('photovoltaic device', 'pv')), 17.585389859143657),
#  ((('pattern recognition', 'AI'),
#    ('photodetector waveguide structures', 'pv')),
#   17.52897023999999),
#  ((('pattern recognition', 'AI'), ('sti', 'pv')), 17.52897023999999),
#  ((('secondary features', 'AI'), ('solar cell', 'pv')), 17.47739572980935),
#  ((('character segmentation', 'AI'), ('wind turbine', 'wind')),
#   17.450330069428816),
#  ((('reading', 'AI'), ('wind turbine', 'wind')), 17.450330069428816),
#  ((('continuous scanning', 'AI'), ('wind turbine', 'wind')),
#   17.450330069428816),
#  ((('expert system techniques', 'AI'), ('solar cell', 'pv')),
#   17.446939097333736),
#  ((('communications system', 'AI'), ('solar cell', 'pv')), 17.446939097333736),
#  ((('failures', 'AI'), ('solar cell', 'pv')), 17.446939097333736),
#  ((('automatic transmission', 'AI'), ('generator', 'wind')),
#   17.43548142108671),
#  ((('registers', 'AI'), ('solar cell', 'pv')), 17.413954696036917),
#  ((('power generator speed', 'AI'), ('controlling', 'wind')),
#   17.412249599999992),
#  ((('second neural networks', 'AI'), ('wind turbine', 'wind')),
#   17.403004624895985),
#  ((('driving conditions', 'AI'), ('wind turbine', 'wind')),
#   17.403004624895985),
#  ((('pedal', 'AI'), ('wind turbine', 'wind')), 17.403004624895985),
#  ((('motor vehicle transmission', 'AI'), ('wind turbine', 'wind')),
#   17.35847626751999),
#  ((('unfavorable driving state', 'AI'), ('wind turbine', 'wind')),
#   17.35847626751999),
#  ((('electronic computing system', 'AI'), ('wind turbine', 'wind')),
#   17.245123184885724),
#  ((('pattern', 'AI'), ('solar cell', 'pv')), 17.206294184165337),
#  ((('network management', 'AI'), ('wind turbine', 'wind')), 17.15949619199999),
#  ((('navigation tools', 'AI'), ('wind turbine', 'wind')), 17.15949619199999),
#  ((('expert system', 'AI'), ('photovoltaic module', 'pv')),
#   17.147115837849555),
#  ((('pattern recognition apparatus', 'AI'), ('photovoltaic cell', 'pv')),
#   17.131594228531206),
#  ((('virtual reality environment', 'AI'), ('wind turbine', 'wind')),
#   16.95213619199999),
#  ((('neural network', 'AI'), ('generator', 'wind')), 16.848447344639972),
#  ((('neural network memory', 'AI'), ('wind turbine', 'wind')),
#   16.735519951257583),
#  ((('expert system', 'AI'), ('controlling', 'pv')), 16.712559282585605),
#  ((('communication system', 'AI'), ('wind turbine', 'wind')),
#   16.659247368904122),
#  ((('adaptive control', 'AI'), ('generator', 'wind')), 16.646875545599993),
#  ((('expert system', 'AI'), ('wind turbine blade', 'wind')), 16.51947098112),
#  ((('fuzzy reasoning', 'AI'), ('wind turbine generator', 'wind')),
#   16.50933411839998),
#  ((('neural network', 'AI'), ('controlling', 'pv')), 16.455627104256003),
#  ((('object recognition', 'AI'), ('wind turbine', 'wind')),
#   16.398904968216574),
#  ((('data processing', 'AI'), ('solar cell', 'pv')), 16.377942664036972),
#  ((('instruction unit', 'AI'), ('solar cell', 'pv')), 16.377942664036972),
#  ((('adaptive control', 'AI'), ('wind energy', 'wind')), 16.364403059097597),
#  ((('expert system', 'AI'), ('display device', 'pv')), 16.298871172300828),
#  ((('test image signals', 'AI'), ('solar cell', 'pv')), 16.29437694456341),
#  ((('luminance level', 'AI'), ('solar cell', 'pv')), 16.29437694456341),
#  ((('diagnostic tester', 'AI'), ('wind turbine', 'wind')), 16.178291675135995),
#  ((('sufficient test data', 'AI'), ('wind turbine', 'wind')),
#   16.178291675135995),
#  ((('second certainty signals', 'AI'), ('wind turbine', 'wind')),
#   16.178291675135995),
#  ((('inverse control network', 'AI'), ('wind turbine', 'wind')),
#   16.140457267200006),
#  ((('remote maintenance monitoring system', 'AI'), ('wind turbine', 'wind')),
#   16.138526928076818),
#  ((('intermittent failures', 'AI'), ('wind turbine', 'wind')),
#   16.138526928076818),
#  ((('diagnostic expert system analysis', 'AI'), ('wind turbine', 'wind')),
#   16.138526928076818),
#  ((('decision tree', 'AI'), ('solar cell', 'pv')), 16.122445391462392),
#  ((('state variables', 'AI'), ('wind turbine', 'wind')), 16.112463667200004),
#  ((('training input data', 'AI'), ('wind turbine', 'wind')), 16.1049306488832),
#  ((('neural network systems', 'AI'), ('wind turbine', 'wind')),
#   16.065444275159084),
#  ((('analog data', 'AI'), ('wind turbine', 'wind')), 16.065444275159084),
#  ((('recall', 'AI'), ('wind turbine', 'wind')), 16.065444275159084),
#  ((('automatic transmission', 'AI'), ('controlling', 'wind')),
#   16.058191280209904),
#  ((('failure analysis system', 'AI'), ('wind turbine', 'wind')),
#   16.04497980948482),
#  ((('subsystem', 'AI'), ('wind turbine', 'wind')), 16.04497980948482),
#  ((('simulation', 'AI'), ('wind turbine', 'wind')), 16.04497980948482),
#  ((('fault relationships', 'AI'), ('wind turbine', 'wind')),
#   15.951784882176003),
#  ((('diagnostic tool', 'AI'), ('wind turbine', 'wind')), 15.951784882176003),
#  ((('failure mode', 'AI'), ('wind turbine', 'wind')), 15.951784882176003),
#  ((('neural network', 'AI'), ('power grid', 'pv')), 15.901998037401608),
#  ((('chinese characters', 'AI'), ('wind turbine', 'wind')),
#   15.841033652840688),
#  ((('gear ratio shift', 'AI'), ('wind turbine', 'wind')), 15.749585348198417),
#  ((('standard code', 'AI'), ('wind turbine', 'wind')), 15.683857667201451),
#  ((('other character edge noise', 'AI'), ('wind turbine', 'wind')),
#   15.683857667201451),
#  ((('vehicle', 'AI'), ('wind turbine', 'wind')), 15.637931656151034),
#  ((('cruise control device', 'AI'), ('wind turbine', 'wind')),
#   15.590926388920348),
#  ((('vehicle speed deviation', 'AI'), ('wind turbine', 'wind')),
#   15.590926388920348),
#  ((('neural network model', 'AI'), ('wind turbine', 'wind')),
#   15.579972403200003),
#  ((('corresponding operation state', 'AI'), ('wind turbine', 'wind')),
#   15.579972403200003),
#  ((('spatial filters', 'AI'), ('wind turbine', 'wind')), 15.528144763079899),
#  ((('fourier transform hologram', 'AI'), ('wind turbine', 'wind')),
#   15.528144763079899),
#  ((('linear optical processing system', 'AI'), ('wind turbine', 'wind')),
#   15.528144763079899),
#  ((('buffer stack', 'AI'), ('wind turbine', 'wind')), 15.510498648883205),
#  ((('expert system', 'AI'), ('power grid', 'wind')), 15.50823674167296),
#  ((('communications network faults', 'AI'), ('wind turbine', 'wind')),
#   15.469738905599998),
#  ((('trouble ticket data structure', 'AI'), ('wind turbine', 'wind')),
#   15.469738905599998),
#  ((('data base', 'AI'), ('wind turbine', 'wind')), 15.337933546291213),
#  ((('expert system process control system', 'AI'), ('wind turbine', 'wind')),
#   15.33193346580479),
#  ((('sensor data', 'AI'), ('wind turbine', 'wind')), 15.33193346580479),
#  ((('vehicle system diagnostics', 'AI'), ('wind turbine', 'wind')),
#   15.26645477376),
#  ((('vehicle attributes', 'AI'), ('wind turbine', 'wind')), 15.26645477376),
#  ((('extrinsic data', 'AI'), ('wind turbine', 'wind')), 15.26645477376),
#  ((('remote computer', 'AI'), ('wind turbine', 'wind')), 15.172460730777622),
#  ((('fault conditions', 'AI'), ('wind turbine', 'wind')), 15.172460730777622),
#  ((('standard code', 'AI'), ('solar cell', 'pv')), 15.100521377601982),
#  ((('other character edge noise', 'AI'), ('solar cell', 'pv')),
#   15.100521377601982),
#  ((('expert system', 'AI'), ('integrated circuit system', 'pv')),
#   15.090250751999992),
#  ((('expert system', 'AI'), ('semiconductor die', 'pv')), 15.090250751999992),
#  ((('expert system', 'AI'), ('discrete passive component', 'pv')),
#   15.090250751999992),
#  ((('wind turbine', 'AI'), ('wind energy', 'wind')), 15.07544445173759),
#  ((('automatic speed control system', 'AI'), ('wind turbine', 'wind')),
#   14.998083489792021),
#  ((('shift', 'AI'), ('wind turbine', 'wind')), 14.998083489792021),
#  ((('throttle valve opening', 'AI'), ('wind turbine', 'wind')),
#   14.998083489792021),
#  ((('patterns', 'AI'), ('wind turbine', 'wind')), 14.969386776467847),
#  ((('pattern recognition method', 'AI'), ('wind turbine', 'wind')),
#   14.79824990355458),
#  ((('inspection process', 'AI'), ('wind turbine', 'wind')), 14.79824990355458),
#  ((('reference object', 'AI'), ('wind turbine', 'wind')), 14.79824990355458),
#  ((('input pattern similarity matrix', 'AI'), ('wind turbine', 'wind')),
#   14.79750620774402),
#  ((('standard reference patterns', 'AI'), ('wind turbine', 'wind')),
#   14.79750620774402),
#  ((('wind turbine', 'AI'), ('generator', 'wind')), 14.697040895999987),
#  ((('fuzzy reasoning', 'AI'), ('controlling', 'wind')), 14.66864474111999),
#  ((('expert system', 'AI'), ('maximum power point tracking', 'pv')),
#   14.66009277235202),
#  ((('recognizing', 'AI'), ('solar cell', 'pv')), 14.639667221790747),
#  ((('pattern recognition apparatus', 'AI'), ('manufacturing', 'pv')),
#   14.618587625717769),
#  ((('pattern recognition', 'AI'), ('display device', 'pv')),
#   14.574665008742423),
#  ((('neural network control', 'AI'), ('wind turbine', 'wind')),
#   14.543712917913595),
#  ((('nonlinear dynamic', 'AI'), ('wind turbine', 'wind')), 14.543712917913595),
#  ((('inverse process', 'AI'), ('wind turbine', 'wind')), 14.543712917913595),
#  ((('robot', 'AI'), ('solar cell', 'pv')), 14.538471684341793),
#  ((('power generator speed', 'AI'), ('wind energy', 'wind')),
#   14.513844451737592),
#  ((('expert system', 'AI'), ('optoelectronic device', 'pv')), 14.493337952256),
#  ((('expert system', 'AI'), ('wearable computing device', 'pv')),
#   14.479774617599988),
#  ((('expert system', 'AI'), ('wcd', 'pv')), 14.479774617599988),
#  ((('expert system', 'AI'), ('human user', 'pv')), 14.479774617599988),
#  ((('sensor nodes', 'AI'), ('wind turbine', 'wind')), 14.42490550271999),
#  ((('apparatus system', 'AI'), ('wind turbine', 'wind')), 14.42490550271999),
#  ((('expert system', 'AI'), ('liquid', 'pv')), 14.395760639999985),
#  ((('output array patterns', 'AI'), ('solar cell', 'pv')), 14.390380533841954),
#  ((('amplifiers', 'AI'), ('solar cell', 'pv')), 14.390380533841954),
#  ((('pattern recognition apparatus', 'AI'),
#    ('wind turbine generator', 'wind')),
#   14.388484420730883),
#  ((('fuzzy set theory', 'AI'), ('wind turbine generator', 'wind')),
#   14.355599155199993),
#  ((('expert system', 'AI'), ('flexible display', 'pv')), 14.23177800302594),
#  ((('expert system', 'AI'), ('solar panel', 'pv')), 14.166498447360018),
#  ((('fuzzy reasoning', 'AI'), ('generator', 'wind')), 14.154701930496001),
#  ((('orientation', 'AI'), ('substrate', 'pv')), 14.098941156556812),
#  ((('reference patterns', 'AI'), ('substrate', 'pv')), 14.043607923916817),
#  ((('pattern recognition', 'AI'), ('flexible display', 'pv')),
#   14.02965813952512),
#  ((('chinese characters', 'AI'), ('substrate', 'pv')), 13.959539361054738),
#  ((('neural network', 'AI'), ('wearable computing device', 'pv')),
#   13.95190904831999),
#  ((('neural network', 'AI'), ('wcd', 'pv')), 13.95190904831999),
#  ((('neural network', 'AI'), ('human user', 'pv')), 13.95190904831999),
#  ((('processing alarms', 'AI'), ('wind turbine', 'wind')), 13.924076182732811),
#  ((('practical real time implementation', 'AI'), ('wind turbine', 'wind')),
#   13.924076182732811),
#  ((('separate faulting', 'AI'), ('wind turbine', 'wind')), 13.924076182732811),
#  ((('neural network system', 'AI'), ('wind turbine', 'wind')),
#   13.922242377154559),
#  ((('power generator speed', 'AI'), ('generator', 'wind')),
#   13.899280895999988),
#  ((('expert system', 'AI'), ('rotor', 'wind')), 13.885398333849604),
#  ((('neural network', 'AI'), ('structural preform layers', 'wind')),
#   13.842524159999988),
#  ((('neural network', 'AI'),
#    ('multiple rigid unidirectional strength elements', 'wind')),
#   13.842524159999988),
#  ((('neural network', 'AI'), ('rods', 'wind')), 13.842524159999988),
#  ((('several attributes', 'AI'), ('wind turbine', 'wind')), 13.8339779022029),
#  ((('action rules', 'AI'), ('wind turbine', 'wind')), 13.8339779022029),
#  ((('optical character recognition', 'AI'), ('photovoltaic cell', 'pv')),
#   13.81737213491283),
#  ((('autonomous vehicle', 'AI'), ('wind turbine', 'wind')), 13.80047918284799),
#  ((('expert system', 'AI'), ('parallel', 'pv')), 13.799620546559995),
#  ((('differential medical diagnosis', 'AI'), ('wind turbine', 'wind')),
#   13.757938930483213),
#  ((('recognizing', 'AI'), ('wind turbine', 'wind')), 13.738066613482305),
#  ((('pattern recognition', 'AI'), ('wind turbine generator', 'wind')),
#   13.692851243797717),
#  ((('sequence estimator receiver', 'AI'), ('wind turbine', 'wind')),
#   13.660928756121628),
#  ((('signals output', 'AI'), ('wind turbine', 'wind')), 13.660928756121628),
#  ((('analog neural network', 'AI'), ('wind turbine', 'wind')),
#   13.660928756121628),
#  ((('expert system', 'AI'), ('energy storage system', 'pv')),
#   13.6127181378355),
#  ((('discriminator storage', 'AI'), ('wind turbine', 'wind')),
#   13.582885207080965),
#  ((('recognition time', 'AI'), ('wind turbine', 'wind')), 13.582885207080965),
#  ((('frame store', 'AI'), ('wind turbine', 'wind')), 13.582885207080965),
#  ((('recognition process', 'AI'), ('wind turbine', 'wind')),
#   13.416573850288124),
#  ((('particular concentrated codes', 'AI'), ('wind turbine', 'wind')),
#   13.416573850288124),
#  ((('digital memory', 'AI'), ('wind turbine', 'wind')), 13.416573850288124),
#  ((('expert system', 'AI'), ('structural preform layers', 'wind')),
#   13.406570495999988),
#  ((('expert system', 'AI'),
#    ('multiple rigid unidirectional strength elements', 'wind')),
#   13.406570495999988),
#  ((('expert system', 'AI'), ('rods', 'wind')), 13.406570495999988),
#  ((('expert system', 'AI'), ('composite wafers', 'pv')), 13.40064),
#  ((('expert system', 'AI'), ('polymeric binder', 'pv')), 13.40064),
#  ((('stroke difference calculator', 'AI'), ('wind turbine', 'wind')),
#   13.38519252324191),
#  ((('character input unit', 'AI'), ('wind turbine', 'wind')),
#   13.38519252324191),
#  ((('reference pattern storage', 'AI'), ('wind turbine', 'wind')),
#   13.38519252324191),
#  ((('processing circuitry', 'AI'), ('wind turbine', 'wind')),
#   13.378149905596452),
#  ((('character recognition', 'AI'), ('substrate', 'pv')), 13.36950108474312),
#  ((('input signals', 'AI'), ('solar cell', 'pv')), 13.339103647334419),
#  ((('organizing', 'AI'), ('solar cell', 'pv')), 13.339103647334419),
#  ((('circuits', 'AI'), ('solar cell', 'pv')), 13.339103647334419),
#  ((('optical reader', 'AI'), ('wind turbine', 'wind')), 13.272396305596452),
#  ((('control device', 'AI'), ('wind turbine', 'wind')), 13.270901759999987),
#  ((('vehicle body acceleration signal', 'AI'), ('wind turbine', 'wind')),
#   13.270901759999987),
#  ((('neural network', 'AI'), ('photovoltaic structures', 'pv')),
#   13.219054350335986),
#  ((('neural network', 'AI'), ('photovoltaic module', 'pv')),
#   13.182980434329577),
#  ((('diagnostic expert system', 'AI'), ('solar cell', 'pv')),
#   13.181421330432018),
#  ((('optimal control inputs', 'AI'), ('wind turbine', 'wind')),
#   13.140289586626551),
#  ((('distinct neuron', 'AI'), ('wind turbine', 'wind')), 13.140289586626551),
#  ((('quandratic cost function', 'AI'), ('wind turbine', 'wind')),
#   13.140289586626551),
#  ((('object video signal representative', 'AI'), ('solar cell', 'pv')),
#   13.139482591671111),
#  ((('correlation evaluation technique', 'AI'), ('solar cell', 'pv')),
#   13.139482591671111),
#  ((('spatial orientation', 'AI'), ('solar cell', 'pv')), 13.139482591671111),
#  ((('expert system', 'AI'), ('solar cell module comprises', 'pv')),
#   13.127462608895996),
#  ((('automatic transmission', 'AI'), ('inverter', 'pv')), 13.125816070963205),
#  ((('adaptive pattern recognition facility', 'AI'), ('wind turbine', 'wind')),
#   13.10960740663296),
#  ((('unknown equipment', 'AI'), ('wind turbine', 'wind')), 13.10960740663296),
#  ((('pattern recognition system', 'AI'), ('wind turbine', 'wind')),
#   13.103824431513592),
#  ((('automated reasoning', 'AI'), ('wind turbine', 'wind')),
#   13.099963686912009),
#  ((('state monitoring system', 'AI'), ('wind turbine', 'wind')),
#   13.099963686912009),
#  ((('problem solving', 'AI'), ('wind turbine', 'wind')), 13.099963686912009),
#  ((('gear shift control system', 'AI'), ('wind turbine', 'wind')),
#   13.084464218112013),
#  ((('vehicle speed sensor', 'AI'), ('wind turbine', 'wind')),
#   13.084464218112013),
#  ((('fuzzy theory', 'AI'), ('wind turbine', 'wind')), 13.084464218112013),
#  ((('fuzzy set theory', 'AI'), ('controlling', 'wind')), 13.031953919999987),
#  ((('vision system', 'AI'), ('wind turbine', 'wind')), 13.022549154201615),
#  ((('ccd imaging device', 'AI'), ('wind turbine', 'wind')),
#   13.022549154201615),
#  ((('image memory', 'AI'), ('wind turbine', 'wind')), 13.022549154201615),
#  ((('expert system', 'AI'), ('utility grid', 'wind')), 13.018386493440014),
#  ((('expert system', 'AI'), ('photovoltaic structures', 'pv')),
#   13.016594659737587),
#  ((('image pattern data', 'AI'), ('solar cell', 'pv')), 13.008147333120021),
#  ((('second correlation', 'AI'), ('solar cell', 'pv')), 13.008147333120021),
#  ((('expert system', 'AI'), ('dc power sources', 'pv')), 12.977310412799984),
#  ((('adaptive vibration cancellation', 'AI'), ('wind turbine', 'wind')),
#   12.97520193945599),
#  ((('expert system', 'AI'), ('sensing', 'pv')), 12.898677288959986),
#  ((('electronic engine control apparatus', 'AI'), ('wind turbine', 'wind')),
#   12.897095201390593),
#  ((('second sensors', 'AI'), ('wind turbine', 'wind')), 12.897095201390593),
#  ((('learned state sequence', 'AI'), ('substrate', 'pv')), 12.824322482995214),
#  ((('independent sequential pattern recognition device', 'AI'),
#    ('solar cell', 'pv')),
#   12.823459033743369),
#  ((('faults', 'AI'), ('solar cell', 'pv')), 12.798265990348819),
#  ((('microscopy system', 'AI'), ('solar cell', 'pv')), 12.794082644459538),
#  ((('locating objects', 'AI'), ('solar cell', 'pv')), 12.794082644459538),
#  ((('biological', 'AI'), ('solar cell', 'pv')), 12.794082644459538),
#  ((('expert system', 'AI'), ('optoelectronic devices', 'pv')),
#   12.755812884479992),
#  ((('image processing', 'AI'), ('wind turbine', 'wind')), 12.73816815206399),
#  ((('analog speech signals', 'AI'), ('wind turbine', 'wind')),
#   12.703408603398175),
#  ((('microprocessor', 'AI'), ('wind turbine', 'wind')), 12.703408603398175),
#  ((('phoneme decision tree', 'AI'), ('wind turbine', 'wind')),
#   12.703408603398175),
#  ((('expert system', 'AI'), ('charging', 'pv')), 12.684056260608001),
#  ((('fuzzy inference', 'AI'), ('wind turbine', 'wind')), 12.666706553320267),
#  ((('pattern recognition', 'AI'), ('power system', 'pv')), 12.65614328217599),
#  ((('second diagnostic subsystem', 'AI'), ('wind turbine', 'wind')),
#   12.63898079688132),
#  ((('maintenance technician', 'AI'), ('wind turbine', 'wind')),
#   12.63898079688132),
#  ((('probabilistic learning element', 'AI'), ('photovoltaic device', 'pv')),
#   12.622198173696034),
#  ((('automatic transmission', 'AI'), ('wind energy', 'wind')),
#   12.58544979777946),
#  ((('noise suppression', 'AI'), ('wind turbine', 'wind')), 12.583629625275178),
#  ((('centroid', 'AI'), ('solar cell', 'pv')), 12.55957717008386),
#  ((('flat object', 'AI'), ('solar cell', 'pv')), 12.55594919952386),
#  ((('masking field', 'AI'), ('wind turbine', 'wind')), 12.5511959642112),
#  ((('activation patterns', 'AI'), ('wind turbine', 'wind')), 12.5511959642112),
#  ((('recognition codes', 'AI'), ('wind turbine', 'wind')), 12.5511959642112),
#  ((('neural network', 'AI'), ('maximum power point tracking', 'pv')),
#   12.548557946880004),
#  ((('recognition', 'AI'), ('photovoltaic cell', 'pv')), 12.548151646027781),
#  ((('log', 'AI'), ('wind turbine', 'wind')), 12.536792050375075),
#  ((('expert system', 'AI'), ('combining', 'pv')), 12.503882649599982),
#  ((('pattern recognition', 'AI'), ('generator', 'wind')), 12.481634173059085),
#  ((('expert system test system', 'AI'), ('wind turbine', 'wind')),
#   12.462563045376),
#  ((('specialized test data', 'AI'), ('wind turbine', 'wind')),
#   12.462563045376),
#  ((('conventional database comparison tools', 'AI'), ('wind turbine', 'wind')),
#   12.462563045376),
#  ((('second fuzzy reasoning', 'AI'), ('wind turbine', 'wind')),
#   12.458240446464),
#  ((('operating conditions', 'AI'), ('wind turbine', 'wind')), 12.458240446464),
#  ((('pattern recognition', 'AI'), ('controlling', 'wind')),
#   12.429054511432348),
#  ((('fuzzy logic controller', 'AI'), ('wind turbine generator', 'wind')),
#   12.419339673600007),
#  ((('probabilistic learning element', 'AI'),
#    ('wind turbine generator', 'wind')),
#   12.419310292992005),
#  ((('optical character recognition', 'AI'), ('manufacturing', 'pv')),
#   12.386613983182855),
#  ((('processing circuitry', 'AI'), ('solar cell', 'pv')), 12.354802993299476),
#  ((('thermal source equipments', 'AI'), ('wind turbine', 'wind')),
#   12.350740377600005),
#  ((('fundamental plan data storage unit', 'AI'), ('wind turbine', 'wind')),
#   12.350740377600005),
#  ((('operation cost', 'AI'), ('wind turbine', 'wind')), 12.350740377600005),
#  ((('dimensional mosaic', 'AI'), ('wind turbine', 'wind')), 12.33185971641386),
#  ((('classifier', 'AI'), ('solar cell', 'pv')), 12.327206223052812),
#  ((('expert system', 'AI'), ('substrates', 'pv')), 12.325511725055998),
#  ((('feature', 'AI'), ('solar cell', 'pv')), 12.303217999872016),
#  ((('classifier neural network', 'AI'), ('wind turbine', 'wind')),
#   12.299458977792007),
#  ((('electrical signal', 'AI'), ('wind turbine', 'wind')), 12.299458977792007),
#  ((('waveform analysis assembly', 'AI'), ('wind turbine', 'wind')),
#   12.299458977792007),
#  ((('expert system', 'AI'), ('dual dc output', 'pv')), 12.284006399999987),
#  ((('electronic computing system', 'AI'), ('solar cell', 'pv')),
#   12.274503605452812),
#  ((('neural network', 'AI'), ('photovoltaic panel', 'pv')),
#   12.255783874559985),
#  ((('pattern recognition', 'AI'), ('optoelectronic devices', 'pv')),
#   12.200313802752008),
#  ((('expert system', 'AI'), ('power generation system', 'wind')),
#   12.192507622195215),
#  ((('image reading unit', 'AI'), ('wind turbine', 'wind')),
#   12.180072777154564),
#  ((('pattern recognition apparatus', 'AI'), ('isolation', 'pv')),
#   12.142655225855993),
#  ((('robotic synthesis instructions', 'AI'), ('solar cell', 'pv')),
#   12.113060290559993),
#  ((('diversity chemical library', 'AI'), ('solar cell', 'pv')),
#   12.113060290559993),
#  ((('optical reader', 'AI'), ('solar cell', 'pv')), 12.061042993299477),
#  ((('genetic algorithm', 'AI'), ('substrate', 'pv')), 12.035890372607998),
#  ((('neural network', 'AI'), ('inverters', 'pv')), 12.013520351232007),
#  ((('dimensional mosaic', 'AI'), ('solar cell', 'pv')), 11.973328757784591),
#  ((('expert system rulebase', 'AI'), ('wind turbine', 'wind')),
#   11.966369366016),
#  ((('corresponding text modules', 'AI'), ('wind turbine', 'wind')),
#   11.966369366016),
#  ((('documentation', 'AI'), ('wind turbine', 'wind')), 11.966369366016),
#  ((('operational expert system', 'AI'), ('wind turbine', 'wind')),
#   11.960463275458569),
#  ((('inference rules', 'AI'), ('wind turbine', 'wind')), 11.960463275458569),
#  ((('language templates', 'AI'), ('wind turbine', 'wind')),
#   11.960463275458569),
#  ((('expert system', 'AI'), ('power conditioning unit', 'pv')),
#   11.956842418176),
#  ((('communication system', 'AI'), ('solar cell', 'pv')), 11.939759847899145),
#  ((('cytological specimen classification', 'AI'), ('solar cell', 'pv')),
#   11.863639771545616),
#  ((('automated microscope', 'AI'), ('solar cell', 'pv')), 11.863639771545616),
#  ((('screening system', 'AI'), ('solar cell', 'pv')), 11.863639771545616),
#  ((('expert system', 'AI'), ('thin film', 'pv')), 11.850810856243198),
#  ((('fuzzy set theory', 'AI'), ('generator', 'wind')), 11.834657279999986),
#  ((('noise suppression', 'AI'), ('solar cell', 'pv')), 11.816272549969938),
#  ((('neural network', 'AI'), ('photovoltaic system', 'pv')),
#   11.771200806912002),
#  ((('expert system', 'AI'), ('inverters', 'pv')), 11.764359032832004),
#  ((('pattern recognition apparatus', 'AI'), ('controlling', 'wind')),
#   11.756860028190728),
#  ((('neural network', 'AI'), ('solar cell module comprises', 'pv')),
#   11.691122687999986),
#  ((('digital signals', 'AI'), ('wind turbine', 'wind')), 11.675475561716137),
#  ((('feature contour', 'AI'), ('wind turbine', 'wind')), 11.666295337844742),
#  ((('oc filter', 'AI'), ('wind turbine', 'wind')), 11.666295337844742),
#  ((('expert system', 'AI'), ('wind farm', 'wind')), 11.664938182901755),
#  ((('inference engine', 'AI'), ('solar cell', 'pv')), 11.612632802918405),
#  ((('patterns', 'AI'), ('solar cell', 'pv')), 11.596794232504328),
#  ((('expert system', 'AI'), ('type semiconductor', 'pv')), 11.572139519999991),
#  ((('recognition', 'AI'), ('manufacturing', 'pv')), 11.539805537894402),
#  ((('expert system', 'AI'), ('buck converter', 'pv')), 11.530252799999984),
#  ((('light detector', 'AI'), ('solar cell', 'pv')), 11.527496657141777),
#  ((('projector', 'AI'), ('solar cell', 'pv')), 11.527496657141777),
#  ((('recognition process', 'AI'), ('solar cell', 'pv')), 11.510906466336783),
#  ((('particular concentrated codes', 'AI'), ('solar cell', 'pv')),
#   11.510906466336783),
#  ((('digital memory', 'AI'), ('solar cell', 'pv')), 11.510906466336783),
#  ((('image input', 'AI'), ('wind turbine', 'wind')), 11.47831244439553),
#  ((('featured template', 'AI'), ('wind turbine', 'wind')), 11.47831244439553),
#  ((('variable synaptic input weights', 'AI'), ('wind turbine', 'wind')),
#   11.473800503132171),
#  ((('analog circuits', 'AI'), ('wind turbine', 'wind')), 11.473800503132171),
#  ((('neural network', 'AI'), ('wind turbine blade', 'wind')),
#   11.471074467840007),
#  ((('pattern recognition apparatus', 'AI'),
#    ('photodetector waveguide structures', 'pv')),
#   11.470926274559993),
#  ((('pattern recognition apparatus', 'AI'), ('sti', 'pv')),
#   11.470926274559993),
#  ((('fuzzy reasoning', 'AI'), ('wind energy', 'wind')), 11.45406882624307),
#  ((('pattern recognition apparatus', 'AI'), ('generator', 'wind')),
#   11.448636103065622),
#  ((('expert systems', 'AI'), ('wind turbine', 'wind')), 11.443062266265622),
#  ((('rule acquisition method', 'AI'), ('wind turbine', 'wind')),
#   11.443062266265622),
#  ((('diagnositc rule', 'AI'), ('wind turbine', 'wind')), 11.443062266265622),
#  ((('artificial neural network', 'AI'), ('solar cell', 'pv')),
#   11.440118454681613),
#  ((('video information', 'AI'), ('wind turbine', 'wind')), 11.377246343469482),
#  ((('segmentation features', 'AI'), ('substrate', 'pv')), 11.370772896841734),
#  ((('image preprocessor', 'AI'), ('substrate', 'pv')), 11.370772896841734),
#  ((('digital scan line signals', 'AI'), ('substrate', 'pv')),
#   11.370772896841734),
#  ((('diagnostic module', 'AI'), ('wind turbine', 'wind')), 11.342461501440006),
#  ((('likelihood', 'AI'), ('wind turbine', 'wind')), 11.342461501440006),
#  ((('system', 'AI'), ('wind turbine', 'wind')), 11.33680345782683),
#  ((('expert system', 'AI'), ('second power', 'pv')), 11.306080051199993),
#  ((('stroke difference calculator', 'AI'), ('solar cell', 'pv')),
#   11.289276434645009),
#  ((('character input unit', 'AI'), ('solar cell', 'pv')), 11.289276434645009),
#  ((('reference pattern storage', 'AI'), ('solar cell', 'pv')),
#   11.289276434645009),
#  ((('generalized minimum variance type', 'AI'), ('wind turbine', 'wind')),
#   11.260466380799995),
#  ((('neural network', 'AI'), ('optoelectronic device', 'pv')),
#   11.24494700543999),
#  ((('fuzzy production rules', 'AI'), ('wind turbine generator', 'wind')),
#   11.24396992512),
#  ((('document', 'AI'), ('wind turbine', 'wind')), 11.238812179144146),
#  ((('pattern ecognition algorithm', 'AI'), ('wind turbine', 'wind')),
#   11.238585753599995),
#  ((('hazardous vapors', 'AI'), ('wind turbine', 'wind')), 11.238585753599995),
#  ((('weight vector', 'AI'), ('wind turbine', 'wind')), 11.238585753599995),
#  ((('pattern recognition', 'AI'), ('lighting device', 'pv')),
#   11.235764551679983),
#  ((('neural network controller', 'AI'), ('inverter', 'pv')),
#   11.230843391999992),
#  ((('data compression', 'AI'), ('wind turbine', 'wind')), 11.227843594321923),
#  ((('date recovery', 'AI'), ('wind turbine', 'wind')), 11.227843594321923),
#  ((('reference color values', 'AI'), ('wind turbine', 'wind')),
#   11.227843594321923),
#  ((('neural network', 'AI'), ('isolation', 'pv')), 11.218265247743995),
#  ((('second memory', 'AI'), ('wind turbine', 'wind')), 11.199166097817626),
#  ((('reference vectors', 'AI'), ('wind turbine', 'wind')), 11.199166097817626),
#  ((('fuzzy logic', 'AI'), ('wind turbine', 'wind')), 11.186458356842497),
#  ((('fault diagnosis expert system', 'AI'), ('wind turbine', 'wind')),
#   11.162791044218894),
#  ((('causes', 'AI'), ('wind turbine', 'wind')), 11.162791044218894),
#  ((('hierarchical search tree structure', 'AI'), ('wind turbine', 'wind')),
#   11.162791044218894),
#  ((('real time', 'AI'), ('substrate', 'pv')), 11.120840083537928),
#  ((('synaptic coefficients', 'AI'), ('solar cell', 'pv')), 11.09804986368001),
#  ((('amplifier circuits', 'AI'), ('solar cell', 'pv')), 11.09804986368001),
#  ((('ferroelectric polymer', 'AI'), ('solar cell', 'pv')), 11.09804986368001),
#  ((('video informatin', 'AI'), ('substrate', 'pv')), 11.092846483537928),
#  ((('coarse information', 'AI'), ('substrate', 'pv')), 11.092846483537928),
#  ((('fuzzy reasoning', 'AI'), ('inverter', 'pv')), 11.054950944768002),
# ...
#   8.990474010624006),
#  ((('character recognition', 'AI'), ('photovoltaic device', 'pv')),
#   8.988724798724517),
#  ((('neural network', 'AI'), ('etching', 'pv')), 8.969848713215999),
#  ((('vehicular driving environment', 'AI'), ('wind turbine', 'wind')),
#   8.967710859264013),
#  ((('total control system', 'AI'), ('wind turbine', 'wind')),
#   8.967710859264013),
#  ((('electronic image processing system', 'AI'), ('solar cell', 'pv')),
#   8.957301028945922),
#  ((('similar prefilter', 'AI'), ('solar cell', 'pv')), 8.957301028945922),
#  ((('expert system', 'AI'), ('wind energy installation', 'wind')),
#   8.934242734079993),
#  ((('expert system', 'AI'), ('wave energy', 'sea')), 8.933713086873599),
#  ((('expert system', 'AI'), ('flexible substrate', 'pv')), 8.924100894720002),
#  ((('pattern recognition', 'AI'), ('emitting device', 'pv')),
#   8.909288954265598),
#  ((('expert system', 'AI'), ('energy assets', 'pv')), 8.890076159999989),
#  ((('expert system', 'AI'), ('present invention assist customers', 'pv')),
#   8.890076159999989),
#  ((('expert system', 'AI'), ('load control', 'pv')), 8.890076159999989),
#  ((('neural network', 'AI'), ('solar panel', 'pv')), 8.88054733209599),
#  ((('pattern recognition', 'AI'), ('wind energy', 'wind')), 8.878728297716144),
#  ((('training examples', 'AI'), ('solar cell', 'pv')), 8.877409748582396),
#  ((('probabilistic learning element', 'AI'), ('wind energy', 'wind')),
#   8.845010472959995),
#  ((('communication system', 'AI'), ('substrate', 'pv')), 8.84000733069313),
#  ((('automatic transmission', 'AI'), ('wind power plant', 'wind')),
#   8.834105725747197),
#  ((('neural network', 'AI'), ('buck converter', 'pv')), 8.83083534335999),
#  ((('analog neural network', 'AI'), ('solar cell', 'pv')), 8.825988759552008),
#  ((('pattern recognition apparatus', 'AI'), ('optoelectronic devices', 'pv')),
#   8.824434388991994),
#  ((('reconstructed second neural network', 'AI'), ('wind turbine', 'wind')),
#   8.821827956736001),
#  ((('communication cable', 'AI'), ('wind turbine', 'wind')),
#   8.821827956736001),
#  ((('high impedance faults', 'AI'), ('wind turbine', 'wind')),
#   8.820610559999997),
#  ((('trigger signal', 'AI'), ('wind turbine', 'wind')), 8.820610559999997),
#  ((('hif condition', 'AI'), ('wind turbine', 'wind')), 8.820610559999997),
#  ((('expert system', 'AI'), ('emitting device', 'pv')), 8.811741634559997),
#  ((('process sensors', 'AI'), ('solar cell', 'pv')), 8.786992140287998),
#  ((('etcher machine state', 'AI'), ('solar cell', 'pv')), 8.786992140287998),
#  ((('pattern recognition', 'AI'), ('power grid', 'pv')), 8.776489505587202),
#  ((('second fuzzy production rules', 'AI'), ('wind turbine', 'wind')),
#   8.770420063567874),
#  ((('vehicle operating conditions', 'AI'), ('wind turbine', 'wind')),
#   8.770420063567874),
#  ((('turbine runner', 'AI'), ('wind turbine', 'wind')), 8.770420063567874),
#  ((('patterns', 'AI'), ('substrate', 'pv')), 8.757244958146558),
#  ((('adaptive control', 'AI'), ('variable speed wind turbine', 'wind')),
#   8.756868096000002),
#  ((('expert system', 'AI'), ('local management unit', 'pv')),
#   8.749663027199984),
#  ((('neural network', 'AI'), ('frequency response optimization system', 'pv')),
#   8.741191680000002),
#  ((('neural network', 'AI'), ('regulation signal', 'pv')), 8.741191680000002),
#  ((('neural network', 'AI'), ('electrical energy storage subplant', 'pv')),
#   8.741191680000002),
#  ((('neural network', 'AI'), ('central plant', 'pv')), 8.741191680000002),
#  ((('neural network', 'AI'), ('resource consumption', 'pv')),
#   8.741191680000002),
#  ((('audio communications', 'AI'), ('wind turbine', 'wind')),
#   8.716829478911993),
#  ((('perceptual entropy envelope', 'AI'), ('wind turbine', 'wind')),
#   8.716829478911993),
#  ((('fsk decoder circuitry', 'AI'), ('wind turbine', 'wind')),
#   8.716829478911993),
#  ((('pattern recognition apparatus', 'AI'), ('display device', 'pv')),
#   8.706233203752959),
#  ((('stroke difference calculator', 'AI'), ('substrate', 'pv')),
#   8.703056271605753),
#  ((('character input unit', 'AI'), ('substrate', 'pv')), 8.703056271605753),
#  ((('reference pattern storage', 'AI'), ('substrate', 'pv')),
#   8.703056271605753),
#  ((('expert system', 'AI'), ('wind turbine generators', 'wind')),
#   8.689567776767994),
#  ((('neural network', 'AI'), ('various dc power outputs', 'pv')),
#   8.687504793599992),
#  ((('neural network', 'AI'), ('configurable power supply', 'pv')),
#   8.687504793599992),
#  ((('expert system techniques', 'AI'), ('photovoltaic device', 'pv')),
#   8.676471193436162),
#  ((('communications system', 'AI'), ('photovoltaic device', 'pv')),
#   8.676471193436162),
#  ((('failures', 'AI'), ('photovoltaic device', 'pv')), 8.676471193436162),
#  ((('sequence estimator receiver', 'AI'), ('solar cell', 'pv')),
#   8.668395159552007),
#  ((('signals output', 'AI'), ('solar cell', 'pv')), 8.668395159552007),
#  ((('pattern recognition', 'AI'), ('thin film', 'pv')), 8.66737187477915),
#  ((('pattern recognition', 'AI'), ('photovoltaic module', 'pv')),
#   8.665055502335987),
#  ((('adaptive control', 'AI'), ('inverter', 'pv')), 8.645631897599994),
#  ((('neural network content', 'AI'), ('wind turbine', 'wind')),
#   8.642196135935993),
#  ((('memory system', 'AI'), ('wind turbine', 'wind')), 8.642196135935993),
#  ((('input bit patterns', 'AI'), ('wind turbine', 'wind')), 8.642196135935993),
#  ((('neural network', 'AI'), ('dual dc output', 'pv')), 8.627760230399987),
#  ((('diagnostic network', 'AI'), ('wind turbine', 'wind')), 8.621692416),
#  ((('machine fault', 'AI'), ('wind turbine', 'wind')), 8.621692416),
#  ((('parallel processing technique', 'AI'), ('wind turbine', 'wind')),
#   8.621692416),
#  ((('spot analysis', 'AI'), ('solar cell', 'pv')), 8.616364388352007),
#  ((('color electrophoretograms', 'AI'), ('solar cell', 'pv')),
#   8.616364388352007),
#  ((('analytical', 'AI'), ('solar cell', 'pv')), 8.616364388352007),
#  ((('pattern feature memories', 'AI'), ('solar cell', 'pv')),
#   8.615154287149066),
#  ((('mask memories', 'AI'), ('solar cell', 'pv')), 8.615154287149066),
#  ((('different mask pattern data', 'AI'), ('solar cell', 'pv')),
#   8.615154287149066),
#  ((('fuzzy reasoning', 'AI'), ('rotor', 'wind')), 8.614520598527989),
#  ((('neural network', 'AI'), ('circuits', 'pv')), 8.610529996799988),
#  ((('neural network', 'AI'), ('lighting device', 'pv')), 8.593726714675192),
#  ((('expert system', 'AI'), ('high efficiency configuration', 'pv')),
#   8.591173631999979),
#  ((('adaptive control', 'AI'), ('nacelle', 'wind')), 8.578830274559998),
#  ((('pattern recognition data', 'AI'), ('solar cell', 'pv')),
#   8.567927746559997),
#  ((('spatial frequency', 'AI'), ('solar cell', 'pv')), 8.567927746559997),
#  ((('processing operations', 'AI'), ('solar cell', 'pv')), 8.567927746559997),
#  ((('fuzzy logic controller', 'AI'), ('controlling', 'wind')),
#   8.555294515199993),
#  ((('automatic transmissions', 'AI'), ('generator', 'wind')),
#   8.534622412799989),
#  ((('neural network systems', 'AI'), ('solar cell', 'pv')), 8.52807375175681),
#  ((('analog data', 'AI'), ('solar cell', 'pv')), 8.52807375175681),
#  ((('recall', 'AI'), ('solar cell', 'pv')), 8.52807375175681),
#  ((('expert system', 'AI'), ('solar collector', 'thermal')),
#   8.525825703935999),
#  ((('learned state sequence', 'AI'), ('photovoltaic device', 'pv')),
#   8.52534299197441),
#  ((('neural network', 'AI'), ('printable semiconductor elements', 'pv')),
#   8.513258803199985),
#  ((('composite fourier spectrum', 'AI'), ('solar cell', 'pv')),
#   8.506164260044807),
#  ((('intensity measurements', 'AI'), ('solar cell', 'pv')), 8.506164260044807),
#  ((('distant objects', 'AI'), ('solar cell', 'pv')), 8.506164260044807),
#  ((('wind turbine', 'AI'), ('rotor blade', 'wind')), 8.503487999999999),
#  ((('expert system techniques', 'AI'), ('inverter', 'pv')), 8.486720593919994),
#  ((('communications system', 'AI'), ('inverter', 'pv')), 8.486720593919994),
#  ((('failures', 'AI'), ('inverter', 'pv')), 8.486720593919994),
#  ((('expert system', 'AI'), ('control system', 'wind')), 8.481491030015995),
#  ((('faults', 'AI'), ('inverter', 'pv')), 8.48014213939199),
#  ((('adaptive control', 'AI'), ('wind turbine blade', 'wind')),
#   8.480060927999999),
#  ((('communications network configuration database', 'AI'),
#    ('wind turbine', 'wind')),
#   8.479041652555782),
#  ((('partial configuration tasks', 'AI'), ('wind turbine', 'wind')),
#   8.479041652555782),
#  ((('waveform equalizer', 'AI'), ('wind turbine', 'wind')), 8.468806746931204),
#  ((('equalization network weights', 'AI'), ('wind turbine', 'wind')),
#   8.468806746931204),
#  ((('distortion characteristic', 'AI'), ('wind turbine', 'wind')),
#   8.468806746931204),
#  ((('stroke recognition', 'AI'), ('solar cell', 'pv')), 8.463017257500667),
#  ((('complex patterns', 'AI'), ('solar cell', 'pv')), 8.463017257500667),
#  ((('diagnostic expert system', 'AI'), ('controlling', 'wind')),
#   8.45742687436799),
#  ((('efficient fault diagnosis systems', 'AI'), ('wind turbine', 'wind')),
#   8.438863100313595),
#  ((('efficient testing rules', 'AI'), ('wind turbine', 'wind')),
#   8.438863100313595),
#  ((('resultant output test tree procedure', 'AI'), ('wind turbine', 'wind')),
#   8.438863100313595),
#  ((('optimum visual stimulus', 'AI'), ('solar cell', 'pv')),
#   8.417991138508802),
#  ((('recomputed wiener kernel representations', 'AI'), ('solar cell', 'pv')),
#   8.417991138508802),
#  ((('analog response signals', 'AI'), ('solar cell', 'pv')),
#   8.417991138508802),
#  ((('fuzzy logic controller', 'AI'), ('generator', 'wind')),
#   8.416274780159991),
#  ((('inference engine program', 'AI'), ('wind turbine', 'wind')),
#   8.414675170099207),
#  ((('treatment information', 'AI'), ('wind turbine', 'wind')),
#   8.414675170099207),
#  ((('pattern recognition', 'AI'), ('monitoring', 'wind')), 8.411688820703224),
#  ((('neural network', 'AI'), ('photovoltaic diodes', 'pv')), 8.40894566399999),
#  ((('centroid', 'AI'), ('substrate', 'pv')), 8.402866465996805),
#  ((('electrochemical device', 'AI'), ('wind turbine', 'wind')),
#   8.396531711999993),
#  ((('expert system', 'AI'), ('dc converter', 'pv')), 8.382315663359986),
#  ((('flat object', 'AI'), ('substrate', 'pv')), 8.342400289996805),
#  ((('document', 'AI'), ('solar cell', 'pv')), 8.33755083168155),
#  ((('gear ratio', 'AI'), ('generator', 'wind')), 8.32231622983679),
#  ((('supplementary inflatable restraint', 'AI'), ('wind turbine', 'wind')),
#   8.283608985599992),
#  ((('vehicle acceleration', 'AI'), ('wind turbine', 'wind')),
#   8.283608985599992),
#  ((('adaptive control', 'AI'), ('wind turbine system', 'wind')),
#   8.280437760000002),
#  ((('pattern recognition apparatus', 'AI'), ('power grid', 'pv')),
#   8.279747444735998),
#  ((('reference contour', 'AI'), ('wind turbine', 'wind')), 8.274252995297285),
#  ((('corresponding reference image', 'AI'), ('wind turbine', 'wind')),
#   8.274252995297285),
#  ((('pattern ecognition algorithm', 'AI'), ('solar cell', 'pv')),
#   8.271659519999998),
#  ((('hazardous vapors', 'AI'), ('solar cell', 'pv')), 8.271659519999998),
#  ((('weight vector', 'AI'), ('solar cell', 'pv')), 8.271659519999998),
#  ((('neural network', 'AI'), ('second power', 'pv')), 8.261805772799988),
#  ((('handwritten pattern', 'AI'), ('substrate', 'pv')), 8.260142947762176),
#  ((('stroke coordinate data', 'AI'), ('substrate', 'pv')), 8.260142947762176),
#  ((('direction angles', 'AI'), ('substrate', 'pv')), 8.260142947762176),
#  ((('independent sequential pattern recognition', 'AI'), ('solar cell', 'pv')),
#   8.251605961113613),
#  ((('frictional coefficients', 'AI'), ('wind turbine', 'wind')),
#   8.234481276518402),
#  ((('fuzzy inference outputs', 'AI'), ('wind turbine', 'wind')),
#   8.234481276518402),
#  ((('noise suppression', 'AI'), ('substrate', 'pv')), 8.226652190146567),
#  ((('pattern information', 'AI'), ('wind turbine', 'wind')), 8.22036418559999),
#  ((('intelligence information processing system', 'AI'),
#    ('wind turbine', 'wind')),
#   8.22036418559999),
#  ((('expert system', 'AI'), ('roadway system electricity grid', 'geo')),
#   8.21489817599998),
#  ((('independent sequential pattern recognition device', 'AI'),
#    ('substrate', 'pv')),
#   8.203139791257597),
#  ((('expert system', 'AI'), ('dc', 'pv')), 8.193581568000003),
#  ((('expert system', 'AI'), ('solar cell module', 'pv')), 8.170277953536003),
#  ((('expert system', 'AI'), ('mounting', 'thermal')), 8.164246398566414),
#  ((('neural network', 'AI'), ('semiconductor dies', 'pv')), 8.153353727999992),
#  ((('neural network', 'AI'), ('plasma grid', 'pv')), 8.145792),
#  ((('neural network', 'AI'), ('ion implant', 'pv')), 8.145792),
#  ((('neural network', 'AI'), ('beamlet divergence', 'pv')), 8.145792),
#  ((('neural network', 'AI'), ('processing chucks', 'pv')), 8.145792),
#  ((('neural network', 'AI'), ('rail assemblies', 'pv')), 8.145792),
#  ((('power generator speed', 'AI'), ('rotor blade', 'wind')),
#   8.143488000000001),
#  ((('training input data', 'AI'), ('inverter', 'pv')), 8.140248575999989),
#  ((('pattern recognition', 'AI'), ('liquid', 'pv')), 8.137221119999984),
#  ((('expert system', 'AI'), ('modules', 'pv')), 8.13500485631999),
#  ((('expert system', 'AI'), ('cells', 'pv')), 8.10022809599999),
#  ((('pattern recognition', 'AI'), ('mounting', 'thermal')), 8.093202242863113),
#  ((('elevator trouble', 'AI'), ('solar cell', 'pv')), 8.0868009885696),
#  ((('interactive initialization procedure', 'AI'), ('solar cell', 'pv')),
#   8.0868009885696),
#  ((('fuzzy production rules', 'AI'), ('wind energy', 'wind')),
#   8.081815064680846),
#  ((('expert system', 'AI'), ('energy storage device', 'pv')),
#   8.081162588159987),
#  ((('cytological specimen classification', 'AI'), ('substrate', 'pv')),
#   8.077198196735988),
#  ((('automated microscope', 'AI'), ('substrate', 'pv')), 8.077198196735988),
#  ((('screening system', 'AI'), ('substrate', 'pv')), 8.077198196735988),
#  ((('probabilistic learning element', 'AI'), ('photovoltaic cell', 'pv')),
#   8.058179314483205),
#  ((('failure mode schema', 'AI'), ('solar cell', 'pv')), 8.054830942617595),
#  ((('independent diagnostic problem solver', 'AI'), ('solar cell', 'pv')),
#   8.054830942617595),
#  ((('hierarchy', 'AI'), ('solar cell', 'pv')), 8.054830942617595),
#  ((('image recognition', 'AI'), ('wind turbine', 'wind')), 8.034879350439939),
#  ((('pattern recognition', 'AI'), ('grid', 'pv')), 8.02395404638617),
#  ((('neural network', 'AI'), ('high efficiency configuration', 'pv')),
#   8.01948211199998),
#  ((('alphanumeric characters', 'AI'), ('wind turbine', 'wind')),
#   8.01437662701159),
#  ((('correlation technique', 'AI'), ('wind turbine', 'wind')),
#   8.01437662701159),
#  ((('pattern recognition', 'AI'), ('integrated circuit system', 'pv')),
#   8.009902079999978),
#  ((('pattern recognition', 'AI'), ('semiconductor die', 'pv')),
#   8.009902079999978),
#  ((('pattern recognition', 'AI'), ('discrete passive component', 'pv')),
#   8.009902079999978),
#  ((('neural network', 'AI'), ('power generation system', 'wind')),
#   8.001280955842548),
#  ((('neural network', 'AI'), ('second grid plate', 'pv')), 7.990272000000001),
#  ((('expert system', 'AI'), ('wind turbine controller', 'wind')),
#   7.9824650895359905),
#  ((('expert system', 'AI'), ('interconnected arrangement', 'pv')),
#   7.981402521599988),
#  ((('microscopy system', 'AI'), ('substrate', 'pv')), 7.971620026613757),
#  ((('locating objects', 'AI'), ('substrate', 'pv')), 7.971620026613757),
#  ((('biological', 'AI'), ('substrate', 'pv')), 7.971620026613757),
#  ((('vehicle control unit', 'AI'), ('wind turbine', 'wind')),
#   7.962541055999992),
#  ((('route planning unit', 'AI'), ('wind turbine', 'wind')),
#   7.962541055999992),
#  ((('pattern recognition apparatus', 'AI'), ('wind energy', 'wind')),
#   7.952239066152966),
#  ((('expert system action indications', 'AI'), ('wind turbine', 'wind')),
#   7.939425071923203),
#  ((('alarm messages', 'AI'), ('wind turbine', 'wind')), 7.939425071923203),
#  ((('prediction module', 'AI'), ('wind turbine', 'wind')), 7.939425071923203),
#  ((('recognition', 'AI'), ('semiconductor dies', 'pv')), 7.937602559999995),
#  ((('automatic transmission', 'AI'), ('power generation system', 'wind')),
#   7.927915541299187),
#  ((('expert system', 'AI'), ('photovoltaic modules', 'pv')),
#   7.925643318067199),
#  ...]

# %%
top_nodes= sorted_node_weights[:70] 
print(top_nodes)

top_nodes_=[t[0] for t in top_nodes]
top_nodes_
# Out:
# [(('solar cell', 'pv'), 2196), (('wind turbine', 'wind'), 1655), (('substrate', 'pv'), 823), (('photovoltaic device', 'pv'), 607), (('manufacturing', 'pv'), 501), (('image processing', 'AI'), 492), (('classifier', 'AI'), 469), (('solar collector', 'thermal'), 443), (('photovoltaic cell', 'pv'), 410), (('neural network', 'AI'), 332), (('thin film', 'pv'), 296), (('fermentation', 'biofuel'), 275), (('semiconductor device', 'pv'), 261), (('wind turbine blade', 'wind'), 259), (('semiconductor', 'pv'), 247), (('biomass', 'biofuel'), 244), (('solar cell module', 'pv'), 242), (('ethanol', 'biofuel'), 238), (('autonomous vehicle', 'AI'), 234), ((('solar heat collector',), 'thermal'), 216), (('machine learning', 'AI'), 204), (('electrode', 'pv'), 198), (('polymer', 'pv'), 189), (('etching', 'pv'), 186), (('wind energy', 'wind'), 184), (('dye sensitized solar cell', 'pv'), 184), (('generator', 'wind'), 181), (('wind turbine generator', 'wind'), 165), (('biodiesel', 'biofuel'), 164), (('rotor', 'wind'), 163), (('photoelectric conversion device', 'pv'), 157), (('display device', 'pv'), 154), (('process', 'biofuel'), 152), (('semiconductor layer', 'pv'), 147), (('rotor blade', 'wind'), 145), (('mounting', 'thermal'), 139), (('photovoltaic module', 'pv'), 137), (('computing device', 'AI'), 125), (('nucleic acid constructs', 'biofuel'), 123), (('inverter', 'pv'), 122), (('silicon solar cell', 'pv'), 115), (('solar radiation', 'thermal'), 113), (('expert system', 'AI'), 109), (('solar heat collector', 'thermal'), 108), (('solar battery', 'pv'), 108), (('wind power plant', 'wind'), 107), (('silicon substrate', 'pv'), 106), (('monitoring', 'AI'), 104), (('photodetector', 'pv'), 103), (('database', 'AI'), 100), (('windmill', 'wind'), 99), (('organic electronic device', 'pv'), 98), (('organic light', 'pv'), 97), (('controlling', 'wind'), 94), (('optoelectronic device', 'pv'), 94), (('biofuels', 'biofuel'), 93), (('emitting device', 'pv'), 90), (('solar concentrator', 'thermal'), 87), (('electronic device', 'pv'), 86), (('isolated polypeptides', 'biofuel'), 86), (('systems', 'AI'), 86), (('amorphous silicon', 'pv'), 85), (('artificial neural network', 'AI'), 85), (('solar cell comprising', 'pv'), 84), (('manufacturing method', 'pv'), 84), (('flexible substrate', 'pv'), 84), (('ethanol production', 'biofuel'), 83), (('nacelle', 'wind'), 83), (('features', 'AI'), 83), (('device', 'pv'), 82)]
# [('solar cell', 'pv'),
#  ('wind turbine', 'wind'),
#  ('substrate', 'pv'),
#  ('photovoltaic device', 'pv'),
#  ('manufacturing', 'pv'),
#  ('image processing', 'AI'),
#  ('classifier', 'AI'),
#  ('solar collector', 'thermal'),
#  ('photovoltaic cell', 'pv'),
#  ('neural network', 'AI'),
#  ('thin film', 'pv'),
#  ('fermentation', 'biofuel'),
#  ('semiconductor device', 'pv'),
#  ('wind turbine blade', 'wind'),
#  ('semiconductor', 'pv'),
#  ('biomass', 'biofuel'),
#  ('solar cell module', 'pv'),
#  ('ethanol', 'biofuel'),
#  ('autonomous vehicle', 'AI'),
#  (('solar heat collector',), 'thermal'),
#  ('machine learning', 'AI'),
#  ('electrode', 'pv'),
#  ('polymer', 'pv'),
#  ('etching', 'pv'),
#  ('wind energy', 'wind'),
#  ('dye sensitized solar cell', 'pv'),
#  ('generator', 'wind'),
#  ('wind turbine generator', 'wind'),
#  ('biodiesel', 'biofuel'),
#  ('rotor', 'wind'),
#  ('photoelectric conversion device', 'pv'),
#  ('display device', 'pv'),
#  ('process', 'biofuel'),
#  ('semiconductor layer', 'pv'),
#  ('rotor blade', 'wind'),
#  ('mounting', 'thermal'),
#  ('photovoltaic module', 'pv'),
#  ('computing device', 'AI'),
#  ('nucleic acid constructs', 'biofuel'),
#  ('inverter', 'pv'),
#  ('silicon solar cell', 'pv'),
#  ('solar radiation', 'thermal'),
#  ('expert system', 'AI'),
#  ('solar heat collector', 'thermal'),
#  ('solar battery', 'pv'),
#  ('wind power plant', 'wind'),
#  ('silicon substrate', 'pv'),
#  ('monitoring', 'AI'),
#  ('photodetector', 'pv'),
#  ('database', 'AI'),
#  ('windmill', 'wind'),
#  ('organic electronic device', 'pv'),
#  ('organic light', 'pv'),
#  ('controlling', 'wind'),
#  ('optoelectronic device', 'pv'),
#  ('biofuels', 'biofuel'),
#  ('emitting device', 'pv'),
#  ('solar concentrator', 'thermal'),
#  ('electronic device', 'pv'),
#  ('isolated polypeptides', 'biofuel'),
#  ('systems', 'AI'),
#  ('amorphous silicon', 'pv'),
#  ('artificial neural network', 'AI'),
#  ('solar cell comprising', 'pv'),
#  ('manufacturing method', 'pv'),
#  ('flexible substrate', 'pv'),
#  ('ethanol production', 'biofuel'),
#  ('nacelle', 'wind'),
#  ('features', 'AI'),
#  ('device', 'pv')]

# %%
#sorted([x  for ((x, l), s) in top_nodes if l=='pv'])
# Out:
# ['amorphous silicon',
#  'device',
#  'display device',
#  'dye sensitized solar cell',
#  'electrode',
#  'electronic device',
#  'emitting device',
#  'etching',
#  'flexible substrate',
#  'inverter',
#  'manufacturing',
#  'manufacturing method',
#  'optoelectronic device',
#  'organic electronic device',
#  'organic light',
#  'photodetector',
#  'photoelectric conversion device',
#  'photovoltaic cell',
#  'photovoltaic device',
#  'photovoltaic module',
#  'polymer',
#  'semiconductor',
#  'semiconductor device',
#  'semiconductor layer',
#  'silicon solar cell',
#  'silicon substrate',
#  'solar battery',
#  'solar cell',
#  'solar cell comprising',
#  'solar cell module',
#  'substrate',
#  'thin film']

# %%
f=open('output/edge-node-weights_keybert_final', "wb")
pickle.dump([sorted_node_weights, sorted_edge_weights], f)
f.close()

# %% [markdown]
# # Constructing the graph

# %%
badnodes=['solar cell comprising','systems','artificial neural network','ethanol production']

# %%
G=nx.DiGraph()

G.add_nodes_from (   [  (kw, {"weight": s, "type": t}) for  ((kw,t), s) in    top_nodes  if 
                   kw not in badnodes ] )

G.nodes['solar cell']
# Out:
# {'weight': 2196, 'type': 'pv'}

# %%
G.add_weighted_edges_from( [(kw[0][0],kw[1][0],s) for  (kw,s) in  sorted_edge_weights if  kw[0] in set(top_nodes_) and  kw[1] in set(top_nodes_)])

# %%
G.remove_nodes_from(badnodes)

G.remove_nodes_from(list(nx.isolates(G)))

# %%
# Saving for Gephi and Cytoscape
nx.write_gexf(G, "output/keyword_graph_keybert_nodeweight2.gexf")
nx.write_graphml(G, "output/keyword_graph_keybert_nodeweight2.graphml")
